# %%
import pandas as pd
from collections import Counter
import os

# %%
df = pd.read_csv('merged_Friday.csv')

# %%
# Separate normal and non-normal instances
normal_traffic = df[df[' Label'] == 'BENIGN']  # Assuming 'benign' corresponds to normal traffic
non_normal_traffic = df[df[' Label'] != 'BENIGN']

# Randomly select 20000 instances from normal traffic
downsampled_normal_traffic = normal_traffic.sample(n=10000, random_state=42)

# Combine downsampled normal traffic with non-normal traffic
downsampled_df = pd.concat([downsampled_normal_traffic, non_normal_traffic])

# Shuffle the combined DataFrame
downsampled_df = downsampled_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
# Divide each value in the 'Fwd Packet Length Mean' column by the corresponding value in the 'Total Fwd Packets' column
downsampled_df['Fwd Packets Normalized'] = (downsampled_df[' Fwd Packet Length Mean'] / downsampled_df[' Total Fwd Packets']).round(3)

downsampled_df['Bwd Packets Normalized'] = (downsampled_df[' Bwd Packet Length Mean'] / downsampled_df[' Total Backward Packets']).round(3)

# %%
# Find the maximum value in a column
maximum_value = downsampled_df['Fwd Packets Normalized'].max()

# Find the minimum value in a column
minimum_value = downsampled_df['Fwd Packets Normalized'].min()

# Print the maximum and minimum values
print("Maximum Value:", maximum_value)
print("Minimum Value:", minimum_value)
# Out:
# Maximum Value: 1448.0
# Minimum Value: 0.0

# %%
# Find the maximum value in a column
maximum_value = downsampled_df['Bwd Packets Normalized'].max()

# Find the minimum value in a column
minimum_value = downsampled_df['Bwd Packets Normalized'].min()

# Print the maximum and minimum values
print("Maximum Value:", maximum_value)
print("Minimum Value:", minimum_value)
# Out:
# Maximum Value: 2900.25
# Minimum Value: 0.0

# %%
# Define ranges for categorization
category_ranges = {
    'fwd_low': (0, 1000.00),
    'fwd_medium': (1001.00, 2000.00),
    'fwd_high': (2001.00, 3000.00)
}

# Function to categorize values based on ranges
def categorize_value(value, ranges):
    if pd.isnull(value):
        return 'fwd_low'  # Treat NaN values as 'low'
    for category, (lower, upper) in ranges.items():
        if lower <= value <= upper:
            return category
    return 'unknown'

# Apply categorization to 'Fwd Packets Normalized' column
downsampled_df['Fwd Packets Category'] = downsampled_df['Fwd Packets Normalized'].apply(lambda x: categorize_value(x, category_ranges))

# %%
# Define ranges for categorization
category_ranges = {
    'Bwd_low': (0, 1000.00),
    'Bwd_medium': (1001.00, 2000.00),
    'Bwd_high': (2001.00, 3000.00)
}

# Function to categorize values based on ranges
def categorize_value(value, ranges):
    if pd.isnull(value):
        return 'Bwd_low'  # Treat NaN values as 'low'
    for category, (lower, upper) in ranges.items():
        if lower <= value <= upper:
            return category
    return 'unknown'

# Apply categorization to 'Bwd Packets Normalized' column
downsampled_df['Bwd Packets Category'] = downsampled_df['Bwd Packets Normalized'].apply(lambda x: categorize_value(x, category_ranges))

# %%
essential_columns = [' Source IP', ' Destination IP',' Destination Port', ' Protocol', 'Fwd Packets Category', 'Bwd Packets Category', ' Flow Duration']

# %%
# Drop non-essential columns
filtered_df = downsampled_df[essential_columns]
print("\nFiltered dataset Summery")
# Function to convert IP addresses to first subnet
def convert_to_first_subnet(ip_address):
    octets = ip_address.split('.')
    octets[2] = '0'
    octets[3] = '0'
    return '.'.join(octets)


# Strip leading and trailing spaces from 'Source IP' and 'Destination IP' columns
filtered_df[' Source IP'] = filtered_df[' Source IP'].astype(str).str.strip()
filtered_df[' Destination IP'] = filtered_df[' Destination IP'].astype(str).str.strip()

# Apply the function to 'Source IP' and 'Destination IP' columns
filtered_df[' Source IP'] = filtered_df[' Source IP'].apply(convert_to_first_subnet)
filtered_df[' Destination IP'] = filtered_df[' Destination IP'].apply(convert_to_first_subnet)

# Check the first few rows of the DataFrame to verify the changes
print("\nFiltered dataset after clearing subnets for first 2 octets")
print(filtered_df.head())
# Out:
# Filtered dataset Summery
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2728\4025526751.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[' Source IP'] = filtered_df[' Source IP'].astype(str).str.strip()
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2728\4025526751.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[' Destination IP'] = filtered_df[' Destination IP'].astype(str).str.strip()
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2728\4025526751.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[' Source IP'] = filtered_df[' Source IP'].apply(convert_to_first_subnet)
# Filtered dataset after clearing subnets for first 2 octets
#     Source IP  Destination IP   Destination Port   Protocol  \
# 0  172.16.0.0     192.168.0.0                 80          6
# 1  172.16.0.0     192.168.0.0               6788          6
# 2  172.16.0.0     192.168.0.0                 80          6
# 3  172.16.0.0     192.168.0.0                800          6
# 4  172.16.0.0     192.168.0.0               5102          6
#
#   Fwd Packets Category Bwd Packets Category   Flow Duration
# 0              fwd_low              Bwd_low        72158382
# 1              fwd_low              Bwd_low              79
# 2              fwd_low              Bwd_low        10652759
# 3              fwd_low              Bwd_low              97
# 4              fwd_low              Bwd_low              31
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2728\4025526751.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[' Destination IP'] = filtered_df[' Destination IP'].apply(convert_to_first_subnet)

# %%
# Convert first five columns to strings and concatenate with hyphens
filtered_df['FlowID'] = filtered_df.iloc[:, :2].astype(str).apply('-'.join, axis=1)

# Drop the original columns
filtered_df = filtered_df.drop(columns=[' Source IP', ' Destination IP']) # , ' Source Port'

# Display the DataFrame
filtered_df.head()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2728\571974056.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['FlowID'] = filtered_df.iloc[:, :2].astype(str).apply('-'.join, axis=1)
#     Destination Port   Protocol Fwd Packets Category Bwd Packets Category  \
# 0                 80          6              fwd_low              Bwd_low
# 1               6788          6              fwd_low              Bwd_low
# 2                 80          6              fwd_low              Bwd_low
# 3                800          6              fwd_low              Bwd_low
# 4               5102          6              fwd_low              Bwd_low
#
#     Flow Duration                  FlowID
# 0        72158382  172.16.0.0-192.168.0.0
# 1              79  172.16.0.0-192.168.0.0
# 2        10652759  172.16.0.0-192.168.0.0
# 3              97  172.16.0.0-192.168.0.0
# 4              31  172.16.0.0-192.168.0.0

# %%
with_ID = filtered_df.copy()
with_ID.insert(0, 'alertID', range(len(with_ID)))
print("\nAdding a ID number for the records")
print(with_ID.head())

dataset_with_ID = with_ID.values.tolist()
# Out:
# Adding a ID number for the records
#    alertID   Destination Port   Protocol Fwd Packets Category  \
# 0        0                 80          6              fwd_low
# 1        1               6788          6              fwd_low
# 2        2                 80          6              fwd_low
# 3        3                800          6              fwd_low
# 4        4               5102          6              fwd_low
#
#   Bwd Packets Category   Flow Duration                  FlowID
# 0              Bwd_low        72158382  172.16.0.0-192.168.0.0
# 1              Bwd_low              79  172.16.0.0-192.168.0.0
# 2              Bwd_low        10652759  172.16.0.0-192.168.0.0
# 3              Bwd_low              97  172.16.0.0-192.168.0.0
# 4              Bwd_low              31  172.16.0.0-192.168.0.0

# %%
print("\nconverting the dataset in to a list")
dataset = [alert[1:] for alert in dataset_with_ID]
# Out:
# converting the dataset in to a list

# %%
# Convert each sublist to a tuple for hashability
data_tuples = [tuple(sublist) for sublist in dataset]

# Count occurrences of each unique record
record_counts = Counter(data_tuples)

print("\nnumber occurrences of each unique record")
print(f"{len(record_counts) }")
# Out:
# number occurrences of each unique record
# 201795

# %%
# Assuming 'filtered_df' is your DataFrame with categorical values

# Create a copy of the DataFrame
new_df = filtered_df.copy()

# Initialize a global mapping to keep track of numerical values
global_mapping = Counter()

# Initialize dictionaries to store both forward and reverse mappings
forward_mapping = {}
reverse_mapping = {}

# Replace categorical values with numerical values using global mapping
for column in new_df.columns:
    # Get unique values in the current column
    unique_values = new_df[column].unique()

    # Map each unique value to a numerical value based on global mapping
    forward_mapping[column] = {value: global_mapping.setdefault(value, len(global_mapping)) for value in unique_values}

    # Create a reverse mapping dictionary
    reverse_mapping[column] = {num: val for val, num in forward_mapping[column].items()}

    # Replace categorical values in the column with numerical values
    new_df[column] = new_df[column].map(forward_mapping[column])

print("\nDisplay the DataFrame with numerical values")
print(new_df.head())
# Out:
# Display the DataFrame with numerical values
#     Destination Port   Protocol  Fwd Packets Category  Bwd Packets Category  \
# 0                  0        256                  3808                  3810
# 1                  1        256                  3808                  3810
# 2                  0        256                  3808                  3810
# 3                  2        256                  3808                  3810
# 4                  3        256                  3808                  3810
#
#     Flow Duration  FlowID
# 0            3813  135988
# 1             340  135988
# 2            3814  135988
# 3            3815  135988
# 4            3816  135988

# %%
# Calculate the count of unique values in the 'type' field
type_counts = downsampled_df[' Label'].value_counts()

print("\nDisplay the count of unique values in Label")
print(type_counts)
# Out:
# Display the count of unique values in Label
#  Label
# PortScan    158930
# DDoS        128027
# BENIGN       10000
# Bot           1966
# Name: count, dtype: int64

# %%
combined_dict = {k: v for inner_dict in reverse_mapping.values() for k, v in inner_dict.items()}

item_dataset = [tuple(x) for x in new_df.to_records(index=False)]

# Add ID field to the start of each tuple
item_dataset_withID = [(i,) + record for i, record in enumerate(item_dataset)]

new_df.to_csv('data.txt', index=False, sep=' ', header=False)

# %%
# Run the algorithm

os.system("java -jar spmf.jar run FPMax data.txt output.txt 0.01%")

itemset_records_object = []
itemset_records_numbers = []

# Read the output file line by line
outFile = open("output.txt", 'r', encoding='utf-8')
for string in outFile:
    itemset = []
    parts = string.split('#SUP:')
    numbers = list(map(int, parts[0].split()))
    support_count = int(parts[1].strip())

    itemset_using_numbers = [numbers, support_count]
    itemset_records_numbers.append(itemset_using_numbers)

    # Translate numerical values to attribute names using reverse mapping
    attribute_names = [str(combined_dict[num]) for num in numbers]
    itemset = [attribute_names, support_count]
    # Output the result
    #print(f"Pattern: {' '.join(attribute_names)}, Support Count: {str(support_count)}")
    itemset_records_object.append(itemset)

outFile.close()

def return_unique_labels(alertID_List):
    # Filter DataFrame based on selected IDs
    selected_records = downsampled_df.iloc[alertID_List]
    # Count unique values in a certain field (e.g., Field1) in the selected records
    unique_value_counts = selected_records[' Label'].value_counts()
    return(unique_value_counts)

for index,record in enumerate(itemset_records_numbers):
    itemset = record[0]
    containing_alerts = []
    for alert in item_dataset_withID:
        alert_items = set(alert[1:])  # Exclude the ID field
        if set(itemset).issubset(alert_items):
            containing_alerts.append(alert[0])  # Append the ID

    print(f"Pattern {index}: {itemset_records_object[index][0]}, \n{return_unique_labels(containing_alerts)}\n===============================================================================================================")
# Out:
# Pattern 0: ['fwd_low', 'Bwd_low', '6', '192.168.0.0-31.13.0.0'],
#  Label
# BENIGN    30
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1: ['fwd_low', 'Bwd_low', '122'],
#  Label
# PortScan    26
# BENIGN       4
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 2: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5901'],
#  Label
# PortScan    30
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 3: ['fwd_low', 'Bwd_low', '6', '443', '192.168.0.0-157.240.0.0'],
#  Label
# BENIGN    30
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 4: ['fwd_low', 'Bwd_low', '6', '192.168.0.0-104.97.0.0'],
#  Label
# BENIGN    34
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 5: ['fwd_low', 'Bwd_low', '6', '192.168.0.0-173.241.0.0'],
#  Label
# BENIGN    34
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 6: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '120'],
#  Label
# PortScan    31
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 7: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '118'],
#  Label
# PortScan    31
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 8: ['fwd_low', 'Bwd_low', '6', '443', '192.168.0.0-162.213.0.0'],
#  Label
# BENIGN    35
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 9: ['fwd_low', 'Bwd_low', '6', '72.21.0.0-192.168.0.0'],
#  Label
# BENIGN    37
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 10: ['fwd_low', 'Bwd_low', '6', '192.168.0.0-69.172.0.0'],
#  Label
# BENIGN    38
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 11: ['fwd_low', 'Bwd_low', '6', '192.168.0.0-23.194.0.0'],
#  Label
# BENIGN    38
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 12: ['fwd_low', 'Bwd_low', '6', '80', '192.168.0.0-23.61.0.0'],
#  Label
# BENIGN    38
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 13: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '121'],
#  Label
# PortScan    33
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 14: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '117'],
#  Label
# PortScan    31
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 15: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2000'],
#  Label
# PortScan    38
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 16: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '115'],
#  Label
# PortScan    35
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 17: ['fwd_low', 'Bwd_low', '6', '192.168.0.0-104.16.0.0'],
#  Label
# BENIGN    41
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 18: ['fwd_low', 'Bwd_low', '6', '80', '192.168.0.0-61.251.0.0'],
#  Label
# BENIGN    41
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 19: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '116'],
#  Label
# PortScan    39
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 20: ['fwd_low', 'Bwd_low', '6', '443', '192.168.0.0-162.208.0.0'],
#  Label
# BENIGN    40
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 21: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '112'],
#  Label
# PortScan    44
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 22: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '114'],
#  Label
# PortScan    47
# DDoS         1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 23: ['fwd_low', 'Bwd_low', '17', '192.168.0.0-192.168.0.0', '137'],
#  Label
# BENIGN    32
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 24: ['fwd_low', 'Bwd_low', '6', '80', '192.168.0.0-50.63.0.0'],
#  Label
# BENIGN    55
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 25: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '113'],
#  Label
# PortScan    52
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 26: ['fwd_low', 'Bwd_low', '6', '151.101.0.0-192.168.0.0'],
#  Label
# BENIGN    59
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 27: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '107'],
#  Label
# PortScan    69
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 28: ['fwd_low', 'Bwd_low', '6', '443', '192.168.0.0-68.67.0.0'],
#  Label
# BENIGN    55
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 29: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '108'],
#  Label
# PortScan    76
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 30: ['fwd_low', 'Bwd_low', '6', '80', '192.168.0.0-72.21.0.0'],
#  Label
# BENIGN    67
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 31: ['Bwd_low', '6', '192.168.0.0-172.16.0.0', 'fwd_medium'],
#  Label
# BENIGN    79
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 32: ['fwd_low', 'Bwd_low', '6', '443', '192.168.0.0-151.101.0.0'],
#  Label
# BENIGN    65
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 33: ['fwd_low', 'Bwd_low', '6', '80', '192.168.0.0-178.255.0.0'],
#  Label
# BENIGN    89
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 34: ['fwd_low', 'Bwd_low', '6', '52.84.0.0-192.168.0.0'],
#  Label
# BENIGN    90
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 35: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '105'],
#  Label
# PortScan    101
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 36: ['fwd_low', 'Bwd_low', '6', '443', '192.168.0.0-52.84.0.0'],
#  Label
# BENIGN    73
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 37: ['fwd_low', 'Bwd_low', '6', '80', '192.168.0.0-52.84.0.0'],
#  Label
# BENIGN    35
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 38: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '102'],
#  Label
# PortScan    122
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 39: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '104'],
#  Label
# PortScan    122
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 40: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '103'],
#  Label
# PortScan    139
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 41: ['fwd_low', 'Bwd_low', '17', '123'],
#  Label
# BENIGN      119
# PortScan      1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 42: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '101'],
#  Label
# PortScan    147
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 43: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1051'],
#  Label
# PortScan    155
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 44: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1034'],
#  Label
# PortScan    155
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 45: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1040'],
#  Label
# PortScan    155
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 46: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '8021'],
#  Label
# PortScan    156
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 47: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '58080'],
#  Label
# PortScan    156
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 48: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '16016'],
#  Label
# PortScan    156
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 49: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5100'],
#  Label
# PortScan    156
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 50: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '4126'],
#  Label
# PortScan    156
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 51: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '541'],
#  Label
# PortScan    156
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 52: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1063'],
#  Label
# PortScan    156
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 53: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '4003'],
#  Label
# PortScan    156
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 54: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5862'],
#  Label
# PortScan    156
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 55: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1723'],
#  Label
# PortScan    156
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 56: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '18988'],
#  Label
# PortScan    156
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 57: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '7100'],
#  Label
# PortScan    156
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 58: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '7070'],
#  Label
# PortScan    156
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 59: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1075'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 60: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '19283'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 61: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '32784'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 62: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '63331'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 63: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1234'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 64: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '6106'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 65: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1700'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 66: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '4550'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 67: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1971'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 68: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1117'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 69: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3918'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 70: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2126'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 71: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '726'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 72: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3260'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 73: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3971'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 74: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1583'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 75: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '10180'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 76: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '873'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 77: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '10626'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 78: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3801'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 79: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2003'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 80: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '6779'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 81: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '10617'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 82: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '8022'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 83: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '54328'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 84: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1036'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 85: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2717'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 86: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '6007'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 87: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2605'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 88: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '9011'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 89: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '45100'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 90: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '8649'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 91: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '10082'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 92: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1719'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 93: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '9575'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 94: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '34572'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 95: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '42510'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 96: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '61900'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 97: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '13456'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 98: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '27355'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 99: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3369'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 100: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '8654'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 101: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '16018'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 102: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5001'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 103: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1500'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 104: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3300'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 105: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '9593'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 106: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '9944'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 107: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '6009'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 108: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1052'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 109: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3389'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 110: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5051'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 111: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1059'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 112: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '8083'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 113: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '9500'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 114: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5718'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 115: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '14238'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 116: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '9100'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 117: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '6025'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 118: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5631'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 119: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '7741'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 120: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1461'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 121: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '9535'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 122: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '17877'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 123: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '12345'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 124: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '4848'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 125: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2043'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 126: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1247'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 127: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3325'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 128: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3493'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 129: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5500'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 130: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '49152'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 131: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3322'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 132: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '25734'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 133: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3905'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 134: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '8082'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 135: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5033'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 136: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2042'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 137: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3869'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 138: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '7002'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 139: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1287'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 140: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2035'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 141: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5222'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 142: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3324'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 143: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1076'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 144: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1244'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 145: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1114'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 146: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '8888'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 147: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '9111'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 148: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1081'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 149: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1310'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 150: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '6510'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 151: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '9220'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 152: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '41511'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 153: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1071'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 154: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3986'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 155: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1216'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 156: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '50389'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 157: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2001'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 158: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2105'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 159: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2399'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 160: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2160'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 161: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '19842'],
#  Label
# PortScan    157
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 162: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '6006'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 163: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1935'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 164: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1594'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 165: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3737'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 166: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '44442'],
#  Label
# PortScan    157
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 167: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '9943'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 168: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '27352'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 169: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5907'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 170: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '52869'],
#  Label
# PortScan    157
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 171: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '50001'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 172: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2525'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 173: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '8009'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 174: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3920'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 175: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1301'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 176: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2022'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 177: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2135'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 178: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '40193'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 179: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1056'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 180: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5915'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 181: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3306'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 182: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '20221'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 183: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '11110'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 184: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2041'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 185: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1580'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 186: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2119'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 187: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '8087'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 188: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '7000'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 189: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '8333'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 190: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '16001'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 191: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3527'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 192: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '3372'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 193: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1187'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 194: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '6689'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 195: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '55600'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 196: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1085'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 197: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5050'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 198: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '8089'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 199: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1174'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 200: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '1947'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 201: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '5633'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 202: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '2394'],
#  Label
# PortScan    158
# Name: count, dtype: int64
# ...
#  Label
# PortScan    1073
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1050: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '34'],
#  Label
# PortScan    1062
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1051: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '27'],
#  Label
# PortScan    1081
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1052: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '36'],
#  Label
# PortScan    1075
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1053: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '20'],
#  Label
# PortScan    1089
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1054: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '23'],
#  Label
# PortScan    1121
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1055: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '24'],
#  Label
# PortScan    1170
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1056: ['fwd_low', 'Bwd_low', '6', '192.168.0.0-192.168.0.0', '22'],
#  Label
# BENIGN    57
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1057: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '22'],
#  Label
# PortScan    1108
# DDoS           3
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1058: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '21'],
#  Label
# PortScan    1147
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1059: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '26'],
#  Label
# PortScan    1187
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1060: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '25'],
#  Label
# PortScan    1189
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1061: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '66'],
#  Label
# PortScan    1209
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1062: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '32'],
#  Label
# PortScan    1224
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1063: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '68'],
#  Label
# PortScan    1246
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1064: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '19'],
#  Label
# PortScan    1233
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1065: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '69'],
#  Label
# PortScan    1260
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1066: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '33'],
#  Label
# PortScan    1244
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1067: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '67'],
#  Label
# PortScan    1258
# DDoS           3
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1068: ['fwd_low', 'Bwd_low', '6', '8080', '192.168.0.0-205.174.0.0'],
#  Label
# Bot       1257
# BENIGN      23
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1069: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '18'],
#  Label
# PortScan    1261
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1070: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '38'],
#  Label
# PortScan    1287
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1071: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '71'],
#  Label
# PortScan    1298
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1072: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '76'],
#  Label
# PortScan    1302
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1073: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '39'],
#  Label
# PortScan    1341
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1074: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '37'],
#  Label
# PortScan    1379
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1075: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '12'],
#  Label
# PortScan    1409
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1076: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '72'],
#  Label
# PortScan    1423
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1077: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '65'],
#  Label
# PortScan    1417
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1078: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '8080'],
#  Label
# PortScan    160
# BENIGN        2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1079: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '40'],
#  Label
# PortScan    1435
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1080: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '70'],
#  Label
# PortScan    1505
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1081: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '75'],
#  Label
# PortScan    1691
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1082: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '73'],
#  Label
# PortScan    1700
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1083: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '13'],
#  Label
# PortScan    1755
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1084: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '57'],
#  Label
# PortScan    1779
# DDoS           2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1085: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '58'],
#  Label
# PortScan    1775
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1086: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '60'],
#  Label
# PortScan    1804
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1087: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '59'],
#  Label
# PortScan    1821
# DDoS           3
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1088: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '64'],
#  Label
# PortScan    1822
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1089: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '61'],
#  Label
# PortScan    1856
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1090: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '51'],
#  Label
# PortScan    1891
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1091: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '52'],
#  Label
# PortScan    1907
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1092: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '74'],
#  Label
# PortScan    1981
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1093: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '62'],
#  Label
# PortScan    2075
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1094: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '56'],
#  Label
# PortScan    2077
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1095: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '443'],
#  Label
# PortScan    241
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1096: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '47'],
#  Label
# PortScan    2220
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1097: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '63'],
#  Label
# PortScan    2298
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1098: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '41'],
#  Label
# PortScan    2433
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1099: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '50'],
#  Label
# PortScan    2723
# DDoS           2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1100: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '46'],
#  Label
# PortScan    2822
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1101: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '55'],
#  Label
# PortScan    3210
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1102: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '54'],
#  Label
# PortScan    3533
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1103: ['fwd_low', 'Bwd_low', '53', '17', '192.168.0.0-192.168.0.0'],
#  Label
# BENIGN    4342
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1104: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '45'],
#  Label
# PortScan    5018
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1105: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '48'],
#  Label
# PortScan    5385
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1106: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '17'],
#  Label
# PortScan    1288
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1107: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '42'],
#  Label
# PortScan    5877
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1108: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '53'],
#  Label
# PortScan    2535
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1109: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '49'],
#  Label
# PortScan    7897
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1110: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '44'],
#  Label
# PortScan    11749
# DDoS            2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1111: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '43'],
#  Label
# PortScan    12816
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1112: ['fwd_low', 'Bwd_low', '6', '172.16.0.0-192.168.0.0', '80'],
#  Label
# DDoS        127652
# PortScan       993
# BENIGN           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1113: ['fwd_low', 'Bwd_low', '6', '6'],
#  Label
# PortScan    158923
# DDoS        127655
# BENIGN        5387
# Bot           1966
# Name: count, dtype: int64
# ===============================================================================================================
