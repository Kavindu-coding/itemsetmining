# %%
import pandas as pd
from collections import Counter
import os

# %%
df = pd.read_csv('merged_Friday.csv')

# %%
# Separate normal and non-normal instances
normal_traffic = df[df[' Label'] == 'BENIGN']  # Assuming 'benign' corresponds to normal traffic
non_normal_traffic = df[df[' Label'] != 'BENIGN']

# Randomly select 20000 instances from normal traffic
downsampled_normal_traffic = normal_traffic.sample(n=10000, random_state=42)

# Combine downsampled normal traffic with non-normal traffic
downsampled_df = pd.concat([downsampled_normal_traffic, non_normal_traffic])

# Shuffle the combined DataFrame
downsampled_df = downsampled_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
# Divide each value in the 'Fwd Packet Length Mean' column by the corresponding value in the 'Total Fwd Packets' column
downsampled_df['Fwd Packets Normalized'] = (downsampled_df[' Fwd Packet Length Mean'] / downsampled_df[' Total Fwd Packets']).round(3)

downsampled_df['Bwd Packets Normalized'] = (downsampled_df[' Bwd Packet Length Mean'] / downsampled_df[' Total Backward Packets']).round(3)

# %%
# Define ranges for categorization
category_ranges = {
    'fwd_low': (0, 1000.00),
    'fwd_medium': (1001.00, 2000.00),
    'fwd_high': (2001.00, 3000.00)
}

# Function to categorize values based on ranges
def categorize_value(value, ranges):
    if pd.isnull(value):
        return 'fwd_low'  # Treat NaN values as 'low'
    for category, (lower, upper) in ranges.items():
        if lower <= value <= upper:
            return category
    return 'unknown'

# Apply categorization to 'Fwd Packets Normalized' column
downsampled_df['Fwd Packets Category'] = downsampled_df['Fwd Packets Normalized'].apply(lambda x: categorize_value(x, category_ranges))

# %%
# Define ranges for categorization
category_ranges = {
    'Bwd_low': (0, 1000.00),
    'Bwd_medium': (1001.00, 2000.00),
    'Bwd_high': (2001.00, 3000.00)
}

# Function to categorize values based on ranges
def categorize_value(value, ranges):
    if pd.isnull(value):
        return 'Bwd_low'  # Treat NaN values as 'low'
    for category, (lower, upper) in ranges.items():
        if lower <= value <= upper:
            return category
    return 'unknown'

# Apply categorization to 'Bwd Packets Normalized' column
downsampled_df['Bwd Packets Category'] = downsampled_df['Bwd Packets Normalized'].apply(lambda x: categorize_value(x, category_ranges))

# %%
essential_columns = [' Source IP', ' Destination IP',' Destination Port', ' Protocol', 'Fwd Packets Category', 'Bwd Packets Category', ' Flow Duration', ' Down/Up Ratio']

# %%
# Drop non-essential columns
filtered_df = downsampled_df[essential_columns]

# %%
with_ID = filtered_df.copy()
with_ID.insert(0, 'alertID', range(len(with_ID)))
print("\nAdding a ID number for the records")
print(with_ID.head())

dataset_with_ID = with_ID.values.tolist()
# Out:
# Adding a ID number for the records
#    alertID   Source IP  Destination IP   Destination Port   Protocol  \
# 0        0  172.16.0.1   192.168.10.50                 80          6
# 1        1  172.16.0.1   192.168.10.50               6788          6
# 2        2  172.16.0.1   192.168.10.50                 80          6
# 3        3  172.16.0.1   192.168.10.50                800          6
# 4        4  172.16.0.1   192.168.10.50               5102          6
#
#   Fwd Packets Category Bwd Packets Category   Flow Duration   Down/Up Ratio
# 0              fwd_low              Bwd_low        72158382               0
# 1              fwd_low              Bwd_low              79               1
# 2              fwd_low              Bwd_low        10652759               0
# 3              fwd_low              Bwd_low              97               1
# 4              fwd_low              Bwd_low              31               1

# %%
print("\nconverting the dataset in to a list")
dataset = [alert[1:] for alert in dataset_with_ID]
# Out:
# converting the dataset in to a list

# %%
# Convert each sublist to a tuple for hashability
data_tuples = [tuple(sublist) for sublist in dataset]

# Count occurrences of each unique record
record_counts = Counter(data_tuples)

print("\nnumber occurrences of each unique record")
print(f"{len(record_counts) }")
# Out:
# number occurrences of each unique record
# 203978

# %%
# Assuming 'filtered_df' is your DataFrame with categorical values

# Create a copy of the DataFrame
new_df = filtered_df.copy()

# Initialize a global mapping to keep track of numerical values
global_mapping = Counter()

# Initialize dictionaries to store both forward and reverse mappings
forward_mapping = {}
reverse_mapping = {}

# Replace categorical values with numerical values using global mapping
for column in new_df.columns:
    # Get unique values in the current column
    unique_values = new_df[column].unique()

    # Map each unique value to a numerical value based on global mapping
    forward_mapping[column] = {value: global_mapping.setdefault(value, len(global_mapping)) for value in unique_values}

    # Create a reverse mapping dictionary
    reverse_mapping[column] = {num: val for val, num in forward_mapping[column].items()}

    # Replace categorical values in the column with numerical values
    new_df[column] = new_df[column].map(forward_mapping[column])

# %%
# Calculate the count of unique values in the 'type' field
type_counts = downsampled_df[' Label'].value_counts()

print("\nDisplay the count of unique values in Label")
print(type_counts)
# Out:
# Display the count of unique values in Label
#  Label
# PortScan    158930
# DDoS        128027
# BENIGN       10000
# Bot           1966
# Name: count, dtype: int64

# %%
combined_dict = {k: v for inner_dict in reverse_mapping.values() for k, v in inner_dict.items()}

item_dataset = [tuple(x) for x in new_df.to_records(index=False)]

# Add ID field to the start of each tuple
item_dataset_withID = [(i,) + record for i, record in enumerate(item_dataset)]

new_df.to_csv('data.txt', index=False, sep=' ', header=False)

# %%
# Run the algorithm

os.system("java -jar spmf.jar run FPMax data.txt output.txt 0.1%")

itemset_records_object = []
itemset_records_numbers = []

# Read the output file line by line
outFile = open("output.txt", 'r', encoding='utf-8')
for string in outFile:
    itemset = []
    parts = string.split('#SUP:')
    numbers = list(map(int, parts[0].split()))
    support_count = int(parts[1].strip())

    itemset_using_numbers = [numbers, support_count]
    itemset_records_numbers.append(itemset_using_numbers)

    # Translate numerical values to attribute names using reverse mapping
    attribute_names = [str(combined_dict[num]) for num in numbers]
    itemset = [attribute_names, support_count]
    # Output the result
    #print(f"Pattern: {' '.join(attribute_names)}, Support Count: {str(support_count)}")
    itemset_records_object.append(itemset)

outFile.close()

def return_unique_labels(alertID_List):
    # Filter DataFrame based on selected IDs
    selected_records = downsampled_df.iloc[alertID_List]
    # Count unique values in a certain field (e.g., Field1) in the selected records
    unique_value_counts = selected_records[' Label'].value_counts()
    return(unique_value_counts)

for index,record in enumerate(itemset_records_numbers):
    itemset = record[0]
    containing_alerts = []
    for alert in item_dataset_withID:
        alert_items = set(alert[1:])  # Exclude the ID field
        if set(itemset).issubset(alert_items):
            containing_alerts.append(alert[0])  # Append the ID

    print(f"Pattern {index}: {itemset_records_object[index][0]}, \n{return_unique_labels(containing_alerts)}\n===============================================================================================================")
# Out:
# Pattern 0: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '96'],
#  Label
# PortScan    309
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '100'],
#  Label
# PortScan    332
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 2: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '95'],
#  Label
# PortScan    330
# BENIGN        1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 3: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '99'],
#  Label
# PortScan    350
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 4: ['fwd_low', 'Bwd_low', '192.168.10.25'],
#  Label
# BENIGN    356
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 5: ['fwd_low', '6', '192.168.10.50', '172.16.0.1', '80', 'Bwd_medium'],
#  Label
# DDoS    371
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 6: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '8'],
#  Label
# PortScan    411
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 7: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '94'],
#  Label
# PortScan    410
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 8: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '87'],
#  Label
# PortScan    459
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 9: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '7'],
#  Label
# PortScan    478
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 10: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '91'],
#  Label
# PortScan    517
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 11: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '98'],
#  Label
# PortScan    538
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 12: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '93'],
#  Label
# PortScan    541
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 13: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '90'],
#  Label
# PortScan    548
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 14: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '86'],
#  Label
# PortScan    560
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 15: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '89'],
#  Label
# PortScan    571
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 16: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '97'],
#  Label
# PortScan    616
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 17: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '9'],
#  Label
# PortScan    623
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 18: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '88'],
#  Label
# PortScan    622
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 19: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '5'],
#  Label
# PortScan    373
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 20: ['fwd_low', 'Bwd_low', '1', '192.168.10.17'],
#  Label
# BENIGN    438
# Bot         2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 21: ['fwd_low', 'Bwd_low', '6', '192.168.10.17'],
#  Label
# BENIGN    386
# Bot         2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 22: ['fwd_low', 'Bwd_low', '1', '192.168.10.16'],
#  Label
# BENIGN    434
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 23: ['fwd_low', 'Bwd_low', '6', '192.168.10.16'],
#  Label
# BENIGN    446
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 24: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '92'],
#  Label
# PortScan    680
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 25: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '10'],
#  Label
# PortScan    695
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 26: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '85'],
#  Label
# PortScan    693
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 27: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '78'],
#  Label
# PortScan    709
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 28: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '4'],
#  Label
# PortScan    550
# DDoS          4
# BENIGN        1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 29: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '82'],
#  Label
# PortScan    713
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 30: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '83'],
#  Label
# PortScan    713
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 31: ['fwd_low', 'Bwd_low', '1', '53', '17', '192.168.10.3', '192.168.10.19'],
#  Label
# BENIGN    304
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 32: ['fwd_low', 'Bwd_low', '6', '192.168.10.19'],
#  Label
# BENIGN    380
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 33: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '84'],
#  Label
# PortScan    718
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 34: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '81'],
#  Label
# PortScan    730
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 35: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '79'],
#  Label
# PortScan    840
# BENIGN        1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 36: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '15'],
#  Label
# PortScan    888
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 37: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '77'],
#  Label
# PortScan    912
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 38: ['fwd_low', 'Bwd_low', '1', '53', '17', '192.168.10.3', '192.168.10.12'],
#  Label
# BENIGN    437
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 39: ['fwd_low', 'Bwd_low', '6', '0', '192.168.10.12'],
#  Label
# BENIGN    306
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 40: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '31'],
#  Label
# PortScan    979
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 41: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '16'],
#  Label
# PortScan    986
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 42: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '29'],
#  Label
# PortScan    1000
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 43: ['fwd_low', 'Bwd_low', '6', '205.174.165.73', '192.168.10.8'],
#  Label
# Bot       374
# BENIGN      8
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 44: ['fwd_low', 'Bwd_low', '192.168.10.3', '192.168.10.8'],
#  Label
# BENIGN    302
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 45: ['fwd_low', 'Bwd_low', '6', '0', '192.168.10.8'],
#  Label
# BENIGN    232
# Bot       114
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 46: ['fwd_low', 'Bwd_low', '6', '1', '192.168.10.8'],
#  Label
# Bot       263
# BENIGN    151
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 47: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '28'],
#  Label
# PortScan    1042
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 48: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '35'],
#  Label
# PortScan    1040
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 49: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '11'],
#  Label
# PortScan    1060
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 50: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '14'],
#  Label
# PortScan    1075
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 51: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '30'],
#  Label
# PortScan    1073
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 52: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '34'],
#  Label
# PortScan    1062
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 53: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '27'],
#  Label
# PortScan    1081
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 54: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '36'],
#  Label
# PortScan    1075
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 55: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '20'],
#  Label
# PortScan    1089
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 56: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '23'],
#  Label
# PortScan    1121
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 57: ['fwd_low', 'Bwd_low', '6', '205.174.165.73', '192.168.10.14'],
#  Label
# Bot       348
# BENIGN      3
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 58: ['fwd_low', 'Bwd_low', '53', '17', '192.168.10.3', '192.168.10.14'],
#  Label
# BENIGN    328
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 59: ['fwd_low', 'Bwd_low', '6', '0', '192.168.10.14'],
#  Label
# BENIGN    283
# Bot       129
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 60: ['fwd_low', 'Bwd_low', '6', '1', '192.168.10.14'],
#  Label
# Bot       219
# BENIGN    198
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 61: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '24'],
#  Label
# PortScan    1170
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 62: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '22'],
#  Label
# PortScan    865
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 63: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '21'],
#  Label
# PortScan    903
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 64: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '26'],
#  Label
# PortScan    1187
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 65: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '25'],
#  Label
# PortScan    1189
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 66: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '66'],
#  Label
# PortScan    1209
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 67: ['fwd_low', 'Bwd_low', '6', '205.174.165.73', '192.168.10.9'],
#  Label
# Bot       372
# BENIGN      6
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 68: ['fwd_low', 'Bwd_low', '1', '53', '17', '192.168.10.3', '192.168.10.9'],
#  Label
# BENIGN    371
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 69: ['fwd_low', 'Bwd_low', '6', '0', '192.168.10.9'],
#  Label
# BENIGN    289
# Bot       141
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 70: ['fwd_low', 'Bwd_low', '6', '1', '192.168.10.9'],
#  Label
# Bot       225
# BENIGN    196
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 71: ['fwd_low', 'Bwd_low', '53', '17', '192.168.10.3', '192.168.10.5'],
#  Label
# BENIGN    365
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 72: ['fwd_low', 'Bwd_low', '6', '0', '192.168.10.5'],
#  Label
# BENIGN    383
# Bot       102
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 73: ['fwd_low', 'Bwd_low', '6', '1', '192.168.10.5'],
#  Label
# BENIGN    212
# Bot       185
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 74: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '32'],
#  Label
# PortScan    1224
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 75: ['fwd_low', 'Bwd_low', '1', '53', '17', '192.168.10.3', '192.168.10.1'],
#  Label
# BENIGN    1257
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 76: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '68'],
#  Label
# PortScan    1246
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 77: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '19'],
#  Label
# PortScan    1233
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 78: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '69'],
#  Label
# PortScan    1260
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 79: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '33'],
#  Label
# PortScan    1244
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 80: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '67'],
#  Label
# PortScan    1258
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 81: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '18'],
#  Label
# PortScan    1261
# BENIGN         1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 82: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '38'],
#  Label
# PortScan    1287
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 83: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '71'],
#  Label
# PortScan    1298
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 84: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '76'],
#  Label
# PortScan    1302
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 85: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '39'],
#  Label
# PortScan    1341
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 86: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '37'],
#  Label
# PortScan    1379
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 87: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '12'],
#  Label
# PortScan    1409
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 88: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '72'],
#  Label
# PortScan    1423
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 89: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '65'],
#  Label
# PortScan    1417
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 90: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '80', '3'],
#  Label
# DDoS        581
# PortScan      3
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 91: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '3'],
#  Label
# PortScan    598
# BENIGN        2
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 92: ['fwd_low', 'Bwd_low', '6', '205.174.165.73', '192.168.10.15', '8080'],
#  Label
# Bot       371
# BENIGN      3
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 93: ['fwd_low', 'Bwd_low', '6', '0', '205.174.165.73', '8080'],
#  Label
# Bot       698
# BENIGN      4
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 94: ['fwd_low', 'Bwd_low', '6', '1', '205.174.165.73', '8080'],
#  Label
# Bot       554
# BENIGN     19
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 95: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '40'],
#  Label
# PortScan    1435
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 96: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '70'],
#  Label
# PortScan    1505
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 97: ['fwd_low', 'Bwd_low', '6', '1', '205.174.165.73', '192.168.10.15'],
#  Label
# Bot       367
# BENIGN      1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 98: ['fwd_low', 'Bwd_low', '53', '17', '192.168.10.3', '192.168.10.15'],
#  Label
# BENIGN    380
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 99: ['fwd_low', 'Bwd_low', '1', '53', '192.168.10.15'],
#  Label
# BENIGN    298
# Bot         1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 100: ['fwd_low', 'Bwd_low', '6', '0', '192.168.10.15'],
#  Label
# BENIGN    383
# Bot       216
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 101: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '75'],
#  Label
# PortScan    1691
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 102: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '73'],
#  Label
# PortScan    1700
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 103: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '13'],
#  Label
# PortScan    1755
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 104: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '57'],
#  Label
# PortScan    1779
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 105: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '58'],
#  Label
# PortScan    1775
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 106: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '60'],
#  Label
# PortScan    1804
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 107: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '59'],
#  Label
# PortScan    1821
# DDoS           2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 108: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '64'],
#  Label
# PortScan    1822
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 109: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '61'],
#  Label
# PortScan    1856
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 110: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '51'],
#  Label
# PortScan    1891
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 111: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '52'],
#  Label
# PortScan    1907
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 112: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '74'],
#  Label
# PortScan    1981
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 113: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '62'],
#  Label
# PortScan    2075
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 114: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '56'],
#  Label
# PortScan    2077
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 115: ['fwd_low', 'Bwd_low', '6', '0', '443'],
#  Label
# BENIGN      1238
# PortScan       1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 116: ['fwd_low', 'Bwd_low', '6', '1', '443'],
#  Label
# BENIGN      623
# PortScan    240
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 117: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '47'],
#  Label
# PortScan    2220
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 118: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '63'],
#  Label
# PortScan    2298
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 119: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '41'],
#  Label
# PortScan    2433
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 120: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '50'],
#  Label
# PortScan    2723
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 121: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '46'],
#  Label
# PortScan    2822
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 122: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '55'],
#  Label
# PortScan    3210
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 123: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '54'],
#  Label
# PortScan    3533
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 124: ['fwd_low', 'Bwd_low', '0', '192.168.10.3'],
#  Label
# BENIGN    319
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 125: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '45'],
#  Label
# PortScan    5018
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 126: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '48'],
#  Label
# PortScan    5385
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 127: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '17'],
#  Label
# PortScan    1288
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 128: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '42'],
#  Label
# PortScan    5877
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 129: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '53'],
#  Label
# PortScan    2535
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 130: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '49'],
#  Label
# PortScan    7897
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 131: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '44'],
#  Label
# PortScan    11749
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 132: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '43'],
#  Label
# PortScan    12816
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 133: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '80', '2'],
#  Label
# DDoS        20499
# PortScan       56
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 134: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '2'],
#  Label
# PortScan    376
# BENIGN        6
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 135: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '80', '0'],
#  Label
# DDoS        69628
# PortScan      312
# BENIGN          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 136: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '80'],
#  Label
# DDoS        36944
# PortScan      625
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 137: ['fwd_low', 'Bwd_low', '6', '192.168.10.50', '172.16.0.1', '1', '1'],
#  Label
# PortScan    157692
# DDoS         36944
# BENIGN         230
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 138: ['fwd_low', 'Bwd_low', '6', '6', '1'],
#  Label
# PortScan    157692
# DDoS         36944
# BENIGN        2080
# Bot           1263
# Name: count, dtype: int64
# ===============================================================================================================
