# %%
import pandas as pd
from collections import Counter
import os

# %%
df = pd.read_csv('merged_Friday.csv')

# %%
# Divide each value in the 'Fwd Packet Length Mean' column by the corresponding value in the 'Total Fwd Packets' column
df['Fwd Packets Normalized'] = (df[' Fwd Packet Length Mean'] / df[' Total Fwd Packets']).round(3)

df['Bwd Packets Normalized'] = (df[' Bwd Packet Length Mean'] / df[' Total Backward Packets']).round(3)

# %%
import numpy as np
# Define ranges for categorization
category_ranges = {
    'fwd_low': (0, 1000.00),
    'fwd_medium': (1001.00, 2000.00),
    'fwd_high': (2001.00, 3000.00),
    'Bwd_very_high': (3001.00, np.inf)
}

# Function to categorize values based on ranges
def categorize_value(value, ranges):
    if pd.isnull(value):
        return 'fwd_low'  # Treat NaN values as 'low'
    for category, (lower, upper) in ranges.items():
        if lower <= value <= upper:
            return category
    return 'unknown'

# Apply categorization to 'Fwd Packets Normalized' column
df['Fwd Packets Category'] = df['Fwd Packets Normalized'].apply(lambda x: categorize_value(x, category_ranges))

# %%
import numpy as np
# Define ranges for categorization
category_ranges = {
    'Bwd_low': (0, 1000.00),
    'Bwd_medium': (1001.00, 2000.00),
    'Bwd_high': (2001.00, 3000.00),
    'Bwd_very_high': (3001.00, np.inf)
}

# Function to categorize values based on ranges
def categorize_value(value, ranges):
    if pd.isnull(value):
        return 'Bwd_low'  # Treat NaN values as 'low'
    for category, (lower, upper) in ranges.items():
        if lower <= value <= upper:
            return category
    return 'unknown'

# Apply categorization to 'Bwd Packets Normalized' column
df['Bwd Packets Category'] = df['Bwd Packets Normalized'].apply(lambda x: categorize_value(x, category_ranges))

# %%
import numpy as np
# Define ranges for categorization
ranges = {
    '0_750': (0.0, 750.0),
    '751_1500': (750.0, 1500.0),
    '1501_15000': (1500.0, 15000.0),
    '15001_120000': (15000.0, 120000.0),
    '120001_300000': (120000.0, 300000.0),
    '300001_6000000': (300000.0, 6000000.0),
    '6000001_65999946': (6000000.0, 65999946.0),
    '66000000_119999902': (65999946.0, 119999902.0),
    '119999902_infinity': (119999902.0, np.inf)
}

# Function to categorize values based on ranges
def categorize_value(value, ranges):
    if pd.isnull(value):
        return 'unknown'  # Treat NaN values as 'unknown'
    for category, (lower, upper) in ranges.items():
        if lower <= value <= upper:
            return category
    return 'unknown'

# Apply categorization to 'Flow Duration' column
df['Flow Duration Category'] = df[' Flow Duration'].apply(lambda x: categorize_value(x, ranges))

# %%
essential_columns = [' Source IP', ' Destination IP',' Destination Port', ' Protocol', 'Fwd Packets Category', 'Bwd Packets Category', 'Flow Duration Category',' SYN Flag Count', ' RST Flag Count',' ACK Flag Count']

# %%
# Drop non-essential columns
filtered_df = df[essential_columns]
print("\nFiltered dataset Summery")
# Function to convert IP addresses to first subnet
def convert_to_first_subnet(ip_address):
    octets = ip_address.split('.')
    octets[2] = '0'
    octets[3] = '0'
    return '.'.join(octets)


# Strip leading and trailing spaces from 'Source IP' and 'Destination IP' columns
filtered_df[' Source IP'] = filtered_df[' Source IP'].astype(str).str.strip()
filtered_df[' Destination IP'] = filtered_df[' Destination IP'].astype(str).str.strip()

# Apply the function to 'Source IP' and 'Destination IP' columns
filtered_df[' Source IP'] = filtered_df[' Source IP'].apply(convert_to_first_subnet)
filtered_df[' Destination IP'] = filtered_df[' Destination IP'].apply(convert_to_first_subnet)
# Out:
# Filtered dataset Summery
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18524\2115978181.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[' Source IP'] = filtered_df[' Source IP'].astype(str).str.strip()
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18524\2115978181.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[' Destination IP'] = filtered_df[' Destination IP'].astype(str).str.strip()
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18524\2115978181.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[' Source IP'] = filtered_df[' Source IP'].apply(convert_to_first_subnet)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_18524\2115978181.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[' Destination IP'] = filtered_df[' Destination IP'].apply(convert_to_first_subnet)

# %%
with_ID = filtered_df.copy()
with_ID.insert(0, 'alertID', range(len(with_ID)))
print("\nAdding a ID number for the records")
print(with_ID.head())

dataset_with_ID = with_ID.values.tolist()
# Out:
# Adding a ID number for the records
#    alertID   Source IP  Destination IP   Destination Port   Protocol  \
# 0        0  104.16.0.0     192.168.0.0              54865          6
# 1        1  104.16.0.0     192.168.0.0              55054          6
# 2        2  104.16.0.0     192.168.0.0              55055          6
# 3        3  104.17.0.0     192.168.0.0              46236          6
# 4        4  104.19.0.0     192.168.0.0              54863          6
#
#   Fwd Packets Category Bwd Packets Category Flow Duration Category  \
# 0              fwd_low              Bwd_low                  0_750
# 1              fwd_low              Bwd_low                  0_750
# 2              fwd_low              Bwd_low                  0_750
# 3              fwd_low              Bwd_low                  0_750
# 4              fwd_low              Bwd_low                  0_750
#
#     SYN Flag Count   RST Flag Count   ACK Flag Count
# 0                0                0                1
# 1                0                0                1
# 2                0                0                1
# 3                0                0                1
# 4                0                0                1

# %%
print("\nconverting the dataset in to a list")
dataset = [alert[1:] for alert in dataset_with_ID]
# Out:
# converting the dataset in to a list

# %%
# Convert each sublist to a tuple for hashability
data_tuples = [tuple(sublist) for sublist in dataset]

# Count occurrences of each unique record
record_counts = Counter(data_tuples)

print("\nnumber occurrences of each unique record")
print(f"{len(record_counts) }")
# Out:
# number occurrences of each unique record
# 98886

# %%
import pandas as pd

# Assuming 'filtered_df' is your DataFrame with categorical values

# Initialize dictionaries to store both forward and reverse mappings
forward_mapping = {}
reverse_mapping = {}

# Initialize the global counter to keep track of numerical values
global_counter = 0

# Iterate over each column in the DataFrame
for column in filtered_df.columns:
    # Initialize a local counter for each column
    local_counter = 0
    
    # Initialize dictionaries for forward and reverse mappings for the current column
    forward_mapping[column] = {}
    reverse_mapping[column] = {}
    
    # Iterate over each unique value in the current column
    for value in filtered_df[column].unique():
        # Map each unique value to a numerical value based on the global counter
        forward_mapping[column][value] = global_counter + local_counter
        reverse_mapping[column][global_counter + local_counter] = value
        
        # Increment the local counter
        local_counter += 1
        
    # Update the global counter to continue numbering from the last value of the previous dictionary
    global_counter += local_counter

# Create a new DataFrame with mapped values
new_df = pd.DataFrame()

# Iterate over each column in the original DataFrame and fill in values in the new DataFrame
for column in filtered_df.columns:
    new_df[column] = filtered_df[column].map(forward_mapping[column])

# Display the DataFrame with numerical values
print(new_df)

# Display forward and reverse mappings for each column
for column in new_df.columns:
    print(f"For {column}:")
    print("Forward Mapping:", forward_mapping[column])
    print("Reverse Mapping:", reverse_mapping[column])
    print()
# Out:
#          Source IP   Destination IP   Destination Port   Protocol  \
# 0                0             1248               2686      40899
# 1                0             1248               2687      40899
# 2                0             1248               2688      40899
# 3                1             1248               2689      40899
# 4                2             1248               2690      40899
# ...            ...              ...                ...        ...
# 703240          18             1248               2750      40900
# 703241          18             1248               2750      40900
# 703242          18             1248               2750      40900
# 703243          18             1458               2760      40900
# 703244          18             1248               2750      40900
#
#         Fwd Packets Category  Bwd Packets Category  Flow Duration Category  \
# 0                      40902                 40905                   40908
# 1                      40902                 40905                   40908
# 2                      40902                 40905                   40908
# 3                      40902                 40905                   40908
# 4                      40902                 40905                   40908
# ...                      ...                   ...                     ...
# 703240                 40902                 40905                   40912
# 703241                 40902                 40905                   40908
# 703242                 40902                 40905                   40908
# 703243                 40902                 40905                   40912
# 703244                 40902                 40905                   40908
#
#          SYN Flag Count   RST Flag Count   ACK Flag Count
# 0                 40918            40920            40922
# 1                 40918            40920            40922
# 2                 40918            40920            40922
# 3                 40918            40920            40922
# 4                 40918            40920            40922
# ...                 ...              ...              ...
# 703240            40918            40920            40923
# 703241            40918            40920            40923
# 703242            40918            40920            40923
# 703243            40918            40920            40923
# 703244            40918            40920            40923
#
# [703245 rows x 10 columns]
# For  Source IP:
# Forward Mapping: {'104.16.0.0': 0, '104.17.0.0': 1, '104.19.0.0': 2, '104.20.0.0': 3, '104.28.0.0': 4, '104.97.0.0': 5, '121.29.0.0': 6, '138.201.0.0': 7, '144.76.0.0': 8, '145.243.0.0': 9, '151.101.0.0': 10, '152.163.0.0': 11, '169.60.0.0': 12, '172.217.0.0': 13, '173.241.0.0': 14, '185.167.0.0': 15, '185.54.0.0': 16, '185.86.0.0': 17, '192.168.0.0': 18, '195.216.0.0': 19, '199.16.0.0': 20, '199.244.0.0': 21, '204.2.0.0': 22, '209.85.0.0': 23, '212.77.0.0': 24, '213.133.0.0': 25, '216.58.0.0': 26, '220.243.0.0': 27, '23.15.0.0': 28, '23.2.0.0': 29, '23.23.0.0': 30, '23.4.0.0': 31, '23.5.0.0': 32, '23.60.0.0': 33, '31.13.0.0': 34, '31.172.0.0': 35, '34.197.0.0': 36, '34.200.0.0': 37, '35.156.0.0': 38, '35.157.0.0': 39, '38.72.0.0': 40, '5.79.0.0': 41, '50.63.0.0': 42, '50.97.0.0': 43, '52.1.0.0': 44, '52.20.0.0': 45, '52.219.0.0': 46, '52.6.0.0': 47, '52.84.0.0': 48, '52.87.0.0': 49, '54.210.0.0': 50, '54.225.0.0': 51, '54.76.0.0': 52, '62.216.0.0': 53, '68.67.0.0': 54, '72.21.0.0': 55, '74.119.0.0': 56, '74.217.0.0': 57, '80.82.0.0': 58, '85.17.0.0': 59, '91.215.0.0': 60, '93.190.0.0': 61, '98.139.0.0': 62, '104.196.0.0': 63, '104.24.0.0': 64, '104.37.0.0': 65, '
# Reverse Mapping: {40918: 0, 40919: 1}
#
# For  RST Flag Count:
# Forward Mapping: {0: 40920, 1: 40921}
# Reverse Mapping: {40920: 0, 40921: 1}
#
# For  ACK Flag Count:
# Forward Mapping: {1: 40922, 0: 40923}
# Reverse Mapping: {40922: 1, 40923: 0}

# %%
# Calculate the count of unique values in the 'type' field
type_counts = df[' Label'].value_counts()

print("\nDisplay the count of unique values in Label")
print(type_counts)
# Out:
# Display the count of unique values in Label
#  Label
# BENIGN      414322
# PortScan    158930
# DDoS        128027
# Bot           1966
# Name: count, dtype: int64

# %%
combined_dict = {k: v for inner_dict in reverse_mapping.values() for k, v in inner_dict.items()}

item_dataset = [tuple(x) for x in new_df.to_records(index=False)]

# Add ID field to the start of each tuple
item_dataset_withID = [(i,) + record for i, record in enumerate(item_dataset)]

new_df.to_csv('data.txt', index=False, sep=' ', header=False)

# %%
# Run the algorithm

os.system("java -jar spmf.jar run FPMax data.txt output.txt 0.1%")

itemset_records_object = []
itemset_records_numbers = []

# Read the output file line by line
outFile = open("output.txt", 'r', encoding='utf-8')
for string in outFile:
    itemset = []
    parts = string.split('#SUP:')
    numbers = list(map(int, parts[0].split()))
    support_count = int(parts[1].strip())

    itemset_using_numbers = [numbers, support_count]
    itemset_records_numbers.append(itemset_using_numbers)

    # Translate numerical values to attribute names using reverse mapping
    attribute_names = [str(combined_dict[num]) for num in numbers]
    itemset = [attribute_names, support_count]
    # Output the result
    #print(f"Pattern: {' '.join(attribute_names)}, Support Count: {str(support_count)}")
    itemset_records_object.append(itemset)

outFile.close()

def return_unique_labels(alertID_List):
    # Filter DataFrame based on selected IDs
    selected_records = df.iloc[alertID_List]
    # Count unique values in a certain field (e.g., Field1) in the selected records
    unique_value_counts = selected_records[' Label'].value_counts().to_dict()
    return(unique_value_counts)

patterns_ID_list = []
pattern_label_list = []

for index,record in enumerate(itemset_records_numbers):
    itemset = record[0]
    containing_alerts = []
    for alert in item_dataset_withID:
        alert_items = set(alert[1:])  # Exclude the ID field
        if set(itemset).issubset(alert_items):
            containing_alerts.append(alert[0])  # Append the ID

    pattern_label_record = list(return_unique_labels(containing_alerts).items())
    patterns_ID_list.append((itemset_records_object[index][0],containing_alerts))
    pattern_label_list.append((itemset_records_object[index][0],pattern_label_record))
    print(f"Pattern {index}: {itemset_records_object[index][0]}, \n{pattern_label_record}\n===============================================================================================================")
# Out:
# Pattern 0: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '0_750', '1', '205.174.0.0'],
# [('Bot', 705)]
# ===============================================================================================================
# Pattern 1: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '1', '23.61.0.0'],
# [('BENIGN', 712)]
# ===============================================================================================================
# Pattern 2: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '104.88.0.0'],
# [('BENIGN', 707)]
# ===============================================================================================================
# Pattern 3: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '1', '74.119.0.0'],
# [('BENIGN', 735)]
# ===============================================================================================================
# Pattern 4: ['0', 'Bwd_low', 'fwd_low', '6', '192.168.0.0', '173.194.0.0'],
# [('BENIGN', 759)]
# ===============================================================================================================
# Pattern 5: ['0', 'Bwd_low', 'fwd_low', '6', '192.168.0.0', '199.59.0.0'],
# [('BENIGN', 762)]
# ===============================================================================================================
# Pattern 6: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '80', '23.50.0.0'],
# [('BENIGN', 761)]
# ===============================================================================================================
# Pattern 7: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '80', '72.167.0.0'],
# [('BENIGN', 780)]
# ===============================================================================================================
# Pattern 8: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '80', '23.52.0.0'],
# [('BENIGN', 813)]
# ===============================================================================================================
# Pattern 9: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '443', '178.172.0.0'],
# [('BENIGN', 847)]
# ===============================================================================================================
# Pattern 10: ['0', 'Bwd_low', 'fwd_low', '6', '192.168.0.0', '465'],
# [('BENIGN', 706)]
# ===============================================================================================================
# Pattern 11: ['0', 'Bwd_low', 'fwd_low', '0', '6', '465'],
# [('BENIGN', 560), ('PortScan', 160)]
# ===============================================================================================================
# Pattern 12: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '104.20.0.0'],
# [('BENIGN', 825)]
# ===============================================================================================================
# Pattern 13: ['0', 'Bwd_low', 'fwd_low', '6', '192.168.0.0', '443', '216.58.0.0'],
# [('BENIGN', 743)]
# ===============================================================================================================
# Pattern 14: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '216.58.0.0'],
# [('BENIGN', 721)]
# ===============================================================================================================
# Pattern 15: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '443', '74.119.0.0'],
# [('BENIGN', 712)]
# ===============================================================================================================
# Pattern 16: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '74.119.0.0'],
# [('BENIGN', 899)]
# ===============================================================================================================
# Pattern 17: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '80', '67.72.0.0'],
# [('BENIGN', 951)]
# ===============================================================================================================
# Pattern 18: ['0', 'Bwd_low', 'fwd_low', '192.168.0.0', '6', '0_750', '1', '104.97.0.0'],
# [('BENIGN', 956)]
# ===============================================================================================================
# Pattern 19: ['0', 'Bwd_low', 'fwd_low', '192.168.0.0', '6', '0_750', '1', '23.208.0.0'],
# [('BENIGN', 852)]
# ===============================================================================================================
# Pattern 20: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '80', '23.60.0.0'],
# [('BENIGN', 717)]
# ===============================================================================================================
# Pattern 21: ['0', 'Bwd_low', 'fwd_low', '192.168.0.0', '6', '0_750', '1', '23.194.0.0'],
# [('BENIGN', 924)]
# ===============================================================================================================
# Pattern 22: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '443', '173.241.0.0'],
# [('BENIGN', 798)]
# ===============================================================================================================
# Pattern 23: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '173.241.0.0'],
# [('BENIGN', 791)]
# ===============================================================================================================
# Pattern 24: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '192.168.0.0', '21'],
# [('BENIGN', 981)]
# ===============================================================================================================
# Pattern 25: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '0', '21'],
# [('BENIGN', 476), ('PortScan', 244)]
# ===============================================================================================================
# Pattern 26: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '0_750', '88'],
# [('BENIGN', 639), ('PortScan', 158)]
# ===============================================================================================================
# Pattern 27: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '0', '192.168.0.0', '88'],
# [('BENIGN', 817)]
# ===============================================================================================================
# Pattern 28: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '88'],
# [('BENIGN', 568), ('PortScan', 159)]
# ===============================================================================================================
# Pattern 29: ['0', 'Bwd_low', 'fwd_low', '192.168.0.0', '6', '1', '1', '162.208.0.0'],
# [('BENIGN', 993)]
# ===============================================================================================================
# Pattern 30: ['0', 'Bwd_low', 'fwd_low', '192.168.0.0', '6', '0_750', '1', '162.208.0.0'],
# [('BENIGN', 789)]
# ===============================================================================================================
# Pattern 31: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '443', '104.97.0.0'],
# [('BENIGN', 979)]
# ===============================================================================================================
# Pattern 32: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '443', '31.13.0.0'],
# [('BENIGN', 839)]
# ===============================================================================================================
# Pattern 33: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '443', '23.208.0.0'],
# [('BENIGN', 873)]
# ===============================================================================================================
# Pattern 34: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '80', '104.16.0.0'],
# [('BENIGN', 842)]
# ===============================================================================================================
# Pattern 35: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '104.16.0.0'],
# [('BENIGN', 980)]
# ===============================================================================================================
# Pattern 36: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '0', '192.168.0.0', '0_750', '17', '137'],
# [('BENIGN', 1229)]
# ===============================================================================================================
# Pattern 37: ['0', 'Bwd_low', 'fwd_low', '192.168.0.0', '192.168.0.0', '0_750', '389'],
# [('BENIGN', 820)]
# ===============================================================================================================
# Pattern 38: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '0_750', '389'],
# [('BENIGN', 696), ('PortScan', 159)]
# ===============================================================================================================
# Pattern 39: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '0', '192.168.0.0', '389'],
# [('BENIGN', 885)]
# ===============================================================================================================
# Pattern 40: ['0', 'Bwd_low', 'fwd_low', '192.168.0.0', '6', '192.168.0.0', '389'],
# [('BENIGN', 951)]
# ===============================================================================================================
# Pattern 41: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '389'],
# [('BENIGN', 621), ('PortScan', 159)]
# ===============================================================================================================
# Pattern 42: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '0_750', '1', '72.21.0.0'],
# [('BENIGN', 1451)]
# ===============================================================================================================
# Pattern 43: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '443', '157.240.0.0'],
# [('BENIGN', 927)]
# ===============================================================================================================
# Pattern 44: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '300001_6000000', '443', '162.213.0.0'],
# [('BENIGN', 796)]
# ===============================================================================================================
# Pattern 45: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '15001_120000', '443', '162.213.0.0'],
# [('BENIGN', 784)]
# ===============================================================================================================
# Pattern 46: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '443', '23.194.0.0'],
# [('BENIGN', 1082)]
# ===============================================================================================================
# Pattern 47: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '80', '23.61.0.0'],
# [('BENIGN', 1165)]
# ===============================================================================================================
# Pattern 48: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '80', '300001_6000000', '61.251.0.0'],
# [('BENIGN', 920)]
# ===============================================================================================================
# Pattern 49: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '80', '61.251.0.0'],
# [('BENIGN', 867)]
# ===============================================================================================================
# Pattern 50: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '443', '69.172.0.0'],
# [('BENIGN', 759)]
# ===============================================================================================================
# Pattern 51: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '69.172.0.0'],
# [('BENIGN', 814)]
# ===============================================================================================================
# Pattern 52: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '80', '15001_120000', '50.63.0.0'],
# [('BENIGN', 906)]
# ===============================================================================================================
# Pattern 53: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '80', '50.63.0.0'],
# [('BENIGN', 906)]
# ===============================================================================================================
# Pattern 54: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '80', '50.63.0.0'],
# [('BENIGN', 1110)]
# ===============================================================================================================
# Pattern 55: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '300001_6000000', '8080', '205.174.0.0'],
# [('BENIGN', 805), ('Bot', 501)]
# ===============================================================================================================
# Pattern 56: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '0', '192.168.0.0', '300001_6000000', '22'],
# [('BENIGN', 976)]
# ===============================================================================================================
# Pattern 57: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '192.168.0.0', '0_750', '1', '22'],
# [('BENIGN', 1034)]
# ===============================================================================================================
# Pattern 58: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '443', '6000001_65999946', '68.67.0.0'],
# [('BENIGN', 717)]
# ===============================================================================================================
# Pattern 59: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '68.67.0.0'],
# [('BENIGN', 947)]
# ===============================================================================================================
# Pattern 60: ['0', 'Bwd_low', 'fwd_low', '192.168.0.0', '6', '0_750', '1', '1', '151.101.0.0'],
# [('BENIGN', 959)]
# ===============================================================================================================
# Pattern 61: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '0_750', '1', '151.101.0.0'],
# [('BENIGN', 1251)]
# ===============================================================================================================
# Pattern 62: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '443', '120001_300000', '162.208.0.0'],
# [('BENIGN', 949)]
# ===============================================================================================================
# Pattern 63: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '162.208.0.0'],
# [('BENIGN', 757)]
# ===============================================================================================================
# Pattern 64: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '80', '66000000_119999902', '72.21.0.0'],
# [('BENIGN', 1050)]
# ===============================================================================================================
# Pattern 65: ['0', 'Bwd_low', '6', '192.168.0.0', '1', '6000001_65999946', '172.16.0.0', '1', 'fwd_medium'],
# [('BENIGN', 1934)]
# ===============================================================================================================
# Pattern 66: ['0', 'Bwd_low', '6', '192.168.0.0', '1', '300001_6000000', '172.16.0.0', '1', 'fwd_medium'],
# [('BENIGN', 1185)]
# ===============================================================================================================
# Pattern 67: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '0_750', '1', '52.84.0.0'],
# [('BENIGN', 3070)]
# ===============================================================================================================
# Pattern 68: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '443', '66000000_119999902', '52.84.0.0'],
# [('BENIGN', 1099)]
# ===============================================================================================================
# Pattern 69: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '300001_6000000', '443', '52.84.0.0'],
# [('BENIGN', 1041)]
# ===============================================================================================================
# Pattern 70: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '80', '52.84.0.0'],
# [('BENIGN', 898)]
# ===============================================================================================================
# Pattern 71: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '443', '66000000_119999902', '151.101.0.0'],
# [('BENIGN', 1016)]
# ===============================================================================================================
# Pattern 72: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '0_750', '443', '151.101.0.0'],
# [('BENIGN', 779)]
# ===============================================================================================================
# Pattern 73: ['0', 'Bwd_low', 'fwd_low', '6', '192.168.0.0', '300001_6000000', '151.101.0.0'],
# [('BENIGN', 738)]
# ===============================================================================================================
# Pattern 74: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '80', '151.101.0.0'],
# [('BENIGN', 811)]
# ===============================================================================================================
# Pattern 75: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '80', '300001_6000000', '178.255.0.0'],
# [('BENIGN', 718)]
# ===============================================================================================================
# Pattern 76: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '80', '15001_120000', '178.255.0.0'],
# [('BENIGN', 1078)]
# ===============================================================================================================
# Pattern 77: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '80', '178.255.0.0'],
# [('BENIGN', 1926)]
# ===============================================================================================================
# Pattern 78: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '0', '192.168.0.0', '17', '53', '751_1500'],
# [('BENIGN', 2183)]
# ===============================================================================================================
# Pattern 79: ['0', 'Bwd_low', 'fwd_low', '192.168.0.0', '6', '1', '751_1500'],
# [('BENIGN', 707), ('DDoS', 1)]
# ===============================================================================================================
# Pattern 80: ['0', 'Bwd_low', 'fwd_low', '0', '6', '1', '751_1500'],
# [('BENIGN', 1271), ('DDoS', 1)]
# ===============================================================================================================
# Pattern 81: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '751_1500'],
# [('BENIGN', 972)]
# ===============================================================================================================
# Pattern 82: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '751_1500'],
# [('BENIGN', 876), ('PortScan', 301), ('DDoS', 6)]
# ===============================================================================================================
# Pattern 83: ['0', 'Bwd_low', 'fwd_low', '0', '0', '192.168.0.0', '17', '66000000_119999902', '123'],
# [('BENIGN', 907)]
# ===============================================================================================================
# Pattern 84: ['0', 'Bwd_low', 'fwd_low', '0', '0', '192.168.0.0', '17', '15001_120000', '123'],
# [('BENIGN', 2901)]
# ===============================================================================================================
# Pattern 85: ['0', 'Bwd_low', 'fwd_low', '192.168.0.0', '6', '1', '1', '1501_15000'],
# [('BENIGN', 793)]
# ===============================================================================================================
# Pattern 86: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '443', '1501_15000'],
# [('BENIGN', 1760)]
# ===============================================================================================================
# Pattern 87: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '80', '1501_15000'],
# [('BENIGN', 1468)]
# ===============================================================================================================
# Pattern 88: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '1', '1501_15000'],
# [('BENIGN', 2277), ('DDoS', 53), ('PortScan', 28)]
# ===============================================================================================================
# Pattern 89: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '192.168.0.0', '1501_15000'],
# [('BENIGN', 713)]
# ===============================================================================================================
# Pattern 90: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '0', '1501_15000'],
# [('DDoS', 456), ('BENIGN', 211), ('PortScan', 107)]
# ===============================================================================================================
# Pattern 91: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '0_750', '1', '172.217.0.0'],
# [('BENIGN', 8345)]
# ===============================================================================================================
# Pattern 92: ['0', 'Bwd_low', 'fwd_low', '6', '192.168.0.0', '1', '443', '6000001_65999946', '1', '172.217.0.0'],
# [('BENIGN', 712)]
# ===============================================================================================================
# Pattern 93: ['0', 'Bwd_low', 'fwd_low', '6', '192.168.0.0', '1', '300001_6000000', '443', '1', '172.217.0.0'],
# [('BENIGN', 1963)]
# ===============================================================================================================
# Pattern 94: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '443', '120001_300000', '172.217.0.0'],
# [('BENIGN', 1119)]
# ===============================================================================================================
# Pattern 95: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '443', '66000000_119999902', '172.217.0.0'],
# [('BENIGN', 3997)]
# ===============================================================================================================
# Pattern 96: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '80', '66000000_119999902', '172.217.0.0'],
# [('BENIGN', 1635)]
# ===============================================================================================================
# Pattern 97: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '443', '6000001_65999946', '172.217.0.0'],
# [('BENIGN', 841)]
# ===============================================================================================================
# Pattern 98: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '300001_6000000', '443', '172.217.0.0'],
# [('BENIGN', 1280)]
# ===============================================================================================================
# Pattern 99: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '80', '300001_6000000', '172.217.0.0'],
# [('BENIGN', 713)]
# ===============================================================================================================
# Pattern 100: ['0', 'Bwd_low', 'fwd_low', '6', '192.168.0.0', '1', '66000000_119999902', '172.16.0.0', '1'],
# [('BENIGN', 1105)]
# ===============================================================================================================
# Pattern 101: ['0', 'Bwd_low', 'fwd_low', '6', '192.168.0.0', '1', '443', '66000000_119999902', '1'],
# [('BENIGN', 1063)]
# ===============================================================================================================
# Pattern 102: ['0', 'Bwd_low', 'fwd_low', '6', '192.168.0.0', '0_750', '1', '443', '1'],
# [('BENIGN', 1025)]
# ===============================================================================================================
# Pattern 103: ['0', 'Bwd_low', '192.168.0.0', '6', '1', '15001_120000', '1'],
# [('BENIGN', 704)]
# ===============================================================================================================
# Pattern 104: ['0', 'Bwd_low', 'fwd_low', '6', '1', '15001_120000', '1'],
# [('BENIGN', 785)]
# ===============================================================================================================
# Pattern 105: ['0', 'Bwd_low', 'fwd_low', '192.168.0.0', '6', '192.168.0.0', '0_750', '1', '1'],
# [('BENIGN', 877)]
# ===============================================================================================================
# Pattern 106: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '172.16.0.0', '120001_300000'],
# [('BENIGN', 835)]
# ===============================================================================================================
# Pattern 107: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '443', '120001_300000'],
# [('BENIGN', 919)]
# ===============================================================================================================
# Pattern 108: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '80', '120001_300000'],
# [('BENIGN', 1112)]
# ===============================================================================================================
# Pattern 109: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '0', '172.16.0.0', '80', '120001_300000'],
# [('DDoS', 5923), ('PortScan', 3)]
# ===============================================================================================================
# Pattern 110: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '80', '120001_300000'],
# [('BENIGN', 1229)]
# ===============================================================================================================
# Pattern 111: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '0', '192.168.0.0', '17', '53', '120001_300000'],
# [('BENIGN', 10847)]
# ===============================================================================================================
# Pattern 112: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '1', '120001_300000'],
# [('DDoS', 640), ('BENIGN', 457)]
# ===============================================================================================================
# Pattern 113: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '66000000_119999902', '172.16.0.0'],
# [('BENIGN', 7304)]
# ===============================================================================================================
# Pattern 114: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '6000001_65999946', '172.16.0.0'],
# [('BENIGN', 7856), ('DDoS', 2)]
# ===============================================================================================================
# Pattern 115: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '300001_6000000', '172.16.0.0'],
# [('BENIGN', 6277), ('DDoS', 1)]
# ===============================================================================================================
# Pattern 116: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '300001_6000000', '172.16.0.0'],
# [('BENIGN', 2918)]
# ===============================================================================================================
# Pattern 117: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '15001_120000', '172.16.0.0'],
# [('BENIGN', 1220)]
# ===============================================================================================================
# Pattern 118: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '0_750', '1', '172.16.0.0'],
# [('BENIGN', 911)]
# ===============================================================================================================
# Pattern 119: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '172.16.0.0', '1', '80', '66000000_119999902'],
# [('DDoS', 21370)]
# ===============================================================================================================
# Pattern 120: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '0', '192.168.0.0', '17', '53', '66000000_119999902'],
# [('BENIGN', 2960)]
# ===============================================================================================================
# Pattern 121: ['0', 'Bwd_low', 'fwd_low', '192.168.0.0', '6', '192.168.0.0', '66000000_119999902'],
# [('BENIGN', 762)]
# ===============================================================================================================
# Pattern 122: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '172.16.0.0', '1', '80', '6000001_65999946'],
# [('DDoS', 25720)]
# ===============================================================================================================
# Pattern 123: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '80', '6000001_65999946'],
# [('BENIGN', 715)]
# ===============================================================================================================
# Pattern 124: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '80', '6000001_65999946'],
# [('BENIGN', 7415)]
# ===============================================================================================================
# Pattern 125: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '0', '192.168.0.0', '17', '53', '6000001_65999946'],
# [('BENIGN', 3391)]
# ===============================================================================================================
# Pattern 126: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '0', '6000001_65999946'],
# [('BENIGN', 554), ('PortScan', 244)]
# ===============================================================================================================
# Pattern 127: ['0', 'Bwd_low', 'fwd_low', '0', '6', '0', '192.168.0.0', '15001_120000', '443'],
# [('BENIGN', 2066)]
# ===============================================================================================================
# Pattern 128: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '0_750', '1', '443'],
# [('BENIGN', 6506)]
# ===============================================================================================================
# Pattern 129: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '172.16.0.0', '1', '80', '300001_6000000'],
# [('DDoS', 20634)]
# ===============================================================================================================
# Pattern 130: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '80', '300001_6000000'],
# [('BENIGN', 733)]
# ===============================================================================================================
# Pattern 131: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '0', '172.16.0.0', '80', '300001_6000000'],
# [('DDoS', 36233), ('PortScan', 28), ('BENIGN', 6)]
# ===============================================================================================================
# Pattern 132: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '0', '192.168.0.0', '17', '53', '300001_6000000'],
# [('BENIGN', 4596)]
# ===============================================================================================================
# Pattern 133: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '172.16.0.0', '1', '80', '15001_120000'],
# [('DDoS', 1316), ('PortScan', 29)]
# ===============================================================================================================
# Pattern 134: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '1', '80', '15001_120000'],
# [('BENIGN', 4494)]
# ===============================================================================================================
# Pattern 135: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '0', '172.16.0.0', '80', '15001_120000'],
# [('DDoS', 15226), ('PortScan', 5)]
# ===============================================================================================================
# Pattern 136: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '0', '192.168.0.0', '17', '53', '15001_120000'],
# [('BENIGN', 85908)]
# ===============================================================================================================
# Pattern 137: ['0', 'Bwd_low', 'fwd_low', '0', '6', '192.168.0.0', '0_750', '1', '80'],
# [('BENIGN', 6517)]
# ===============================================================================================================
# Pattern 138: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '0', '192.168.0.0', '0_750', '17', '53'],
# [('BENIGN', 70613)]
# ===============================================================================================================
# Pattern 139: ['0', 'Bwd_low', 'fwd_low', '0', '192.168.0.0', '6', '0', '0_750', '172.16.0.0'],
# [('PortScan', 158102)]
# ===============================================================================================================

# %%
# Function to get the original field and value using the reverse mapping dictionaries
def get_field_and_value(item):
    for column, mapping in reverse_mapping.items():
        if int(item) in mapping:
            return str(column), mapping[int(item)]
    return None, None

# %%
# Initialize a list to store the patterns with original field and value

pattern_record = pd.DataFrame(columns=['Support Count', 'Label'])
patterns_with_fields = []

for index, record in enumerate(itemset_records_numbers):
    # Split the line into items and support count
    items = record[0]
    support_count = int(record[1])

    # Initialize a list to store the original field and value of each item
    record_with_field = []

    # Map each item in the pattern to its original field and value
    for item in items:
        # Get the field and value using the reverse mapping dictionaries
        field, value = get_field_and_value(item)
        record_with_field.append({"field": field, "value": value})

        # Check if the field already exists in the DataFrame
        if field not in pattern_record.columns:
            # If not, add a new column with the field name and fill with NaN
            pattern_record[field] = pd.NA
        
        # Add the value to the corresponding field
        pattern_record.at[index, field] = value
    
        # Add the support_count to the pattern_data dictionary
    pattern_record.at[index, 'Support Count'] = support_count

    if len(pattern_label_list[index][1]) == 1:
        pattern_record.at[index, 'Label'] = pattern_label_list[index][1][0][0]
    else:
        pattern_record.at[index, 'Label'] = 'Mixed Labels'
    # Store the pattern with original field and value along with the support count
    
    patterns_with_fields.append({"pattern": record_with_field, "support_count": support_count})

pattern_record = pattern_record.fillna('NaN').infer_objects(copy=False)

# Print the patterns with original field and value
for pattern_info in patterns_with_fields:
    print(pattern_info)
    print()
# Out:
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Source IP', 'value': '205.174.0.0'}], 'support_count': 705}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Source IP', 'value': '23.61.0.0'}], 'support_count': 712}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination IP', 'value': '104.88.0.0'}], 'support_count': 707}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Source IP', 'value': '74.119.0.0'}], 'support_count': 735}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination IP', 'value': '173.194.0.0'}], 'support_count': 759}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination IP', 'value': '199.59.0.0'}], 'support_count': 762}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': ' Destination IP', 'value': '23.50.0.0'}], 'support_count': 761}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': ' Destination IP', 'value': '72.167.0.0'}], 'support_count': 780}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': ' Destination IP', 'value': '23.52.0.0'}], 'support_count': 813}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '178.172.0.0'}], 'support_count': 847}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 465}], 'support_count': 706}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Destination Port', 'value': 465}], 'support_count': 720}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination IP', 'value': '104.20.0.0'}], 'support_count': 825}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '216.58.0.0'}], 'support_count': 743}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination IP', 'value': '216.58.0.0'}], 'support_count': 721}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '74.119.0.0'}], 'support_count': 712}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination IP', 'value': '74.119.0.0'}], 'support_count': 899}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': ' Destination IP', 'value': '67.72.0.0'}], 'support_count': 951}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Source IP', 'value': '104.97.0.0'}], 'support_count': 956}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Source IP', 'value': '23.208.0.0'}], 'support_count': 852}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': ' Destination IP', 'value': '23.60.0.0'}], 'support_count': 717}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Source IP', 'value': '23.194.0.0'}], 'support_count': 924}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '173.241.0.0'}], 'support_count': 798}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination IP', 'value': '173.241.0.0'}], 'support_count': 791}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 21}], 'support_count': 981}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Destination Port', 'value': 21}], 'support_count': 720}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' Destination Port', 'value': 88}], 'support_count': 797}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 88}], 'support_count': 817}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' Destination Port', 'value': 88}], 'support_count': 727}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' SYN Flag Count', 'value': 1}, {'field': ' Source IP', 'value': '162.208.0.0'}], 'support_count': 993}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Source IP', 'value': '162.208.0.0'}], 'support_count': 789}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '104.97.0.0'}], 'support_count': 979}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '31.13.0.0'}], 'support_count': 839}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '23.208.0.0'}], 'support_count': 873}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': ' Destination IP', 'value': '104.16.0.0'}], 'support_count': 842}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination IP', 'value': '104.16.0.0'}], 'support_count': 980}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' Protocol', 'value': 17}, {'field': ' Destination Port', 'value': 137}], 'support_count': 1229}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' Destination Port', 'value': 389}], 'support_count': 820}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' Destination Port', 'value': 389}], 'support_count': 855}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 389}], 'support_count': 885}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 389}], 'support_count': 951}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' Destination Port', 'value': 389}], 'support_count': 780}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Source IP', 'value': '72.21.0.0'}], 'support_count': 1451}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '157.240.0.0'}], 'support_count': 927}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '162.213.0.0'}], 'support_count': 796}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '15001_120000'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '162.213.0.0'}], 'support_count': 784}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '23.194.0.0'}], 'support_count': 1082}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': ' Destination IP', 'value': '23.61.0.0'}], 'support_count': 1165}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}, {'field': ' Destination IP', 'value': '61.251.0.0'}], 'support_count': 920}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 80}, {'field': ' Destination IP', 'value': '61.251.0.0'}], 'support_count': 867}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '69.172.0.0'}], 'support_count': 759}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination IP', 'value': '69.172.0.0'}], 'support_count': 814}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '15001_120000'}, {'field': ' Destination IP', 'value': '50.63.0.0'}], 'support_count': 906}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 80}, {'field': ' Destination IP', 'value': '50.63.0.0'}], 'support_count': 906}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': ' Destination IP', 'value': '50.63.0.0'}], 'support_count': 1110}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}, {'field': ' Destination Port', 'value': 8080}, {'field': ' Destination IP', 'value': '205.174.0.0'}], 'support_count': 1306}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}, {'field': ' Destination Port', 'value': 22}], 'support_count': 976}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 22}], 'support_count': 1034}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': 'Flow Duration Category', 'value': '6000001_65999946'}, {'field': ' Destination IP', 'value': '68.67.0.0'}], 'support_count': 717}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination IP', 'value': '68.67.0.0'}], 'support_count': 947}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' SYN Flag Count', 'value': 1}, {'field': ' Source IP', 'value': '151.101.0.0'}], 'support_count': 959}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Source IP', 'value': '151.101.0.0'}], 'support_count': 1251}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': 'Flow Duration Category', 'value': '120001_300000'}, {'field': ' Destination IP', 'value': '162.208.0.0'}], 'support_count': 949}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination IP', 'value': '162.208.0.0'}], 'support_count': 757}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '66000000_119999902'}, {'field': ' Destination IP', 'value': '72.21.0.0'}], 'support_count': 1050}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '6000001_65999946'}, {'field': ' Destination IP', 'value': '172.16.0.0'}, {'field': ' SYN Flag Count', 'value': 1}, {'field': 'Fwd Packets Category', 'value': 'fwd_medium'}], 'support_count': 1934}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}, {'field': ' Destination IP', 'value': '172.16.0.0'}, {'field': ' SYN Flag Count', 'value': 1}, {'field': 'Fwd Packets Category', 'value': 'fwd_medium'}], 'support_count': 1185}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Source IP', 'value': '52.84.0.0'}], 'support_count': 3070}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': 'Flow Duration Category', 'value': '66000000_119999902'}, {'field': ' Destination IP', 'value': '52.84.0.0'}], 'support_count': 1099}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '52.84.0.0'}], 'support_count': 1041}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': ' Destination IP', 'value': '52.84.0.0'}], 'support_count': 898}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': 'Flow Duration Category', 'value': '66000000_119999902'}, {'field': ' Destination IP', 'value': '151.101.0.0'}], 'support_count': 1016}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '151.101.0.0'}], 'support_count': 779}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}, {'field': ' Destination IP', 'value': '151.101.0.0'}], 'support_count': 738}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': ' Destination IP', 'value': '151.101.0.0'}], 'support_count': 811}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}, {'field': ' Destination IP', 'value': '178.255.0.0'}], 'support_count': 718}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '15001_120000'}, {'field': ' Destination IP', 'value': '178.255.0.0'}], 'support_count': 1078}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 80}, {'field': ' Destination IP', 'value': '178.255.0.0'}], 'support_count': 1926}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 17}, {'field': ' Destination Port', 'value': 53}, {'field': 'Flow Duration Category', 'value': '751_1500'}], 'support_count': 2183}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '751_1500'}], 'support_count': 708}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '751_1500'}], 'support_count': 1272}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '751_1500'}], 'support_count': 972}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': 'Flow Duration Category', 'value': '751_1500'}], 'support_count': 1183}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 17}, {'field': 'Flow Duration Category', 'value': '66000000_119999902'}, {'field': ' Destination Port', 'value': 123}], 'support_count': 907}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 17}, {'field': 'Flow Duration Category', 'value': '15001_120000'}, {'field': ' Destination Port', 'value': 123}], 'support_count': 2901}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' SYN Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '1501_15000'}], 'support_count': 793}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 443}, {'field': 'Flow Duration Category', 'value': '1501_15000'}], 'support_count': 1760}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '1501_15000'}], 'support_count': 1468}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '1501_15000'}], 'support_count': 2358}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '1501_15000'}], 'support_count': 713}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': 'Flow Duration Category', 'value': '1501_15000'}], 'support_count': 774}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Source IP', 'value': '172.217.0.0'}], 'support_count': 8345}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 443}, {'field': 'Flow Duration Category', 'value': '6000001_65999946'}, {'field': ' SYN Flag Count', 'value': 1}, {'field': ' Destination IP', 'value': '172.217.0.0'}], 'support_count': 712}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}, {'field': ' Destination Port', 'value': 443}, {'field': ' SYN Flag Count', 'value': 1}, {'field': ' Destination IP', 'value': '172.217.0.0'}], 'support_count': 1963}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': 'Flow Duration Category', 'value': '120001_300000'}, {'field': ' Destination IP', 'value': '172.217.0.0'}], 'support_count': 1119}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': 'Flow Duration Category', 'value': '66000000_119999902'}, {'field': ' Destination IP', 'value': '172.217.0.0'}], 'support_count': 3997}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '66000000_119999902'}, {'field': ' Destination IP', 'value': '172.217.0.0'}], 'support_count': 1635}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 443}, {'field': 'Flow Duration Category', 'value': '6000001_65999946'}, {'field': ' Destination IP', 'value': '172.217.0.0'}], 'support_count': 841}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}, {'field': ' Destination Port', 'value': 443}, {'field': ' Destination IP', 'value': '172.217.0.0'}], 'support_count': 1280}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}, {'field': ' Destination IP', 'value': '172.217.0.0'}], 'support_count': 713}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '66000000_119999902'}, {'field': ' Destination IP', 'value': '172.16.0.0'}, {'field': ' SYN Flag Count', 'value': 1}], 'support_count': 1105}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 443}, {'field': 'Flow Duration Category', 'value': '66000000_119999902'}, {'field': ' SYN Flag Count', 'value': 1}], 'support_count': 1063}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 443}, {'field': ' SYN Flag Count', 'value': 1}], 'support_count': 1025}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '15001_120000'}, {'field': ' SYN Flag Count', 'value': 1}], 'support_count': 704}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '15001_120000'}, {'field': ' SYN Flag Count', 'value': 1}], 'support_count': 785}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' SYN Flag Count', 'value': 1}], 'support_count': 877}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination IP', 'value': '172.16.0.0'}, {'field': 'Flow Duration Category', 'value': '120001_300000'}], 'support_count': 835}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 443}, {'field': 'Flow Duration Category', 'value': '120001_300000'}], 'support_count': 919}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '120001_300000'}], 'support_count': 1112}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '172.16.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '120001_300000'}], 'support_count': 5926}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '120001_300000'}], 'support_count': 1229}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 17}, {'field': ' Destination Port', 'value': 53}, {'field': 'Flow Duration Category', 'value': '120001_300000'}], 'support_count': 10847}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '120001_300000'}], 'support_count': 1097}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '66000000_119999902'}, {'field': ' Destination IP', 'value': '172.16.0.0'}], 'support_count': 7304}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '6000001_65999946'}, {'field': ' Destination IP', 'value': '172.16.0.0'}], 'support_count': 7858}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}, {'field': ' Destination IP', 'value': '172.16.0.0'}], 'support_count': 6278}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}, {'field': ' Destination IP', 'value': '172.16.0.0'}], 'support_count': 2918}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '15001_120000'}, {'field': ' Destination IP', 'value': '172.16.0.0'}], 'support_count': 1220}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination IP', 'value': '172.16.0.0'}], 'support_count': 911}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '172.16.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '66000000_119999902'}], 'support_count': 21370}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 17}, {'field': ' Destination Port', 'value': 53}, {'field': 'Flow Duration Category', 'value': '66000000_119999902'}], 'support_count': 2960}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '66000000_119999902'}], 'support_count': 762}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '172.16.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '6000001_65999946'}], 'support_count': 25720}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '6000001_65999946'}], 'support_count': 715}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '6000001_65999946'}], 'support_count': 7415}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 17}, {'field': ' Destination Port', 'value': 53}, {'field': 'Flow Duration Category', 'value': '6000001_65999946'}], 'support_count': 3391}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': 'Flow Duration Category', 'value': '6000001_65999946'}], 'support_count': 798}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '15001_120000'}, {'field': ' Destination Port', 'value': 443}], 'support_count': 2066}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 443}], 'support_count': 6506}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '172.16.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}], 'support_count': 20634}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}], 'support_count': 733}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '172.16.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}], 'support_count': 36267}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 17}, {'field': ' Destination Port', 'value': 53}, {'field': 'Flow Duration Category', 'value': '300001_6000000'}], 'support_count': 4596}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '172.16.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '15001_120000'}], 'support_count': 1345}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '15001_120000'}], 'support_count': 4494}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '172.16.0.0'}, {'field': ' Destination Port', 'value': 80}, {'field': 'Flow Duration Category', 'value': '15001_120000'}], 'support_count': 15231}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 17}, {'field': ' Destination Port', 'value': 53}, {'field': 'Flow Duration Category', 'value': '15001_120000'}], 'support_count': 85908}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Protocol', 'value': 6}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' ACK Flag Count', 'value': 1}, {'field': ' Destination Port', 'value': 80}], 'support_count': 6517}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' ACK Flag Count', 'value': 0}, {'field': ' Source IP', 'value': '192.168.0.0'}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' Protocol', 'value': 17}, {'field': ' Destination Port', 'value': 53}], 'support_count': 70613}
#
# {'pattern': [{'field': ' RST Flag Count', 'value': 0}, {'field': 'Bwd Packets Category', 'value': 'Bwd_low'}, {'field': 'Fwd Packets Category', 'value': 'fwd_low'}, {'field': ' SYN Flag Count', 'value': 0}, {'field': ' Destination IP', 'value': '192.168.0.0'}, {'field': ' Protocol', 'value': 6}, {'field': ' ACK Flag Count', 'value': 0}, {'field': 'Flow Duration Category', 'value': '0_750'}, {'field': ' Source IP', 'value': '172.16.0.0'}], 'support_count': 158102}

# %%
# Save the pattern record DataFrame to a CSV file
pattern_record.to_csv('pattern_record_0.1%_NotDownsampled_DifferentFeatures.csv', index=False)
