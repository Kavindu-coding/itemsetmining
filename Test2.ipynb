# %%
import pandas as pd
from collections import Counter
import os

# %%
df = pd.read_csv('merged_Friday.csv')

# %%
# Divide each value in the 'Fwd Packet Length Mean' column by the corresponding value in the 'Total Fwd Packets' column
df['Fwd Packets Normalized'] = (df[' Fwd Packet Length Mean'] / df[' Total Fwd Packets']).round(3)

df['Bwd Packets Normalized'] = (df[' Bwd Packet Length Mean'] / df[' Total Backward Packets']).round(3)

# %%
# Define ranges for categorization
category_ranges = {
    'fwd_low': (0, 1000.00),
    'fwd_medium': (1001.00, 2000.00),
    'fwd_high': (2001.00, 3000.00)
}

# Function to categorize values based on ranges
def categorize_value(value, ranges):
    if pd.isnull(value):
        return 'fwd_low'  # Treat NaN values as 'low'
    for category, (lower, upper) in ranges.items():
        if lower <= value <= upper:
            return category
    return 'unknown'

# Apply categorization to 'Fwd Packets Normalized' column
df['Fwd Packets Category'] = df['Fwd Packets Normalized'].apply(lambda x: categorize_value(x, category_ranges))

# %%
# Define ranges for categorization
category_ranges = {
    'Bwd_low': (0, 1000.00),
    'Bwd_medium': (1001.00, 2000.00),
    'Bwd_high': (2001.00, 3000.00)
}

# Function to categorize values based on ranges
def categorize_value(value, ranges):
    if pd.isnull(value):
        return 'Bwd_low'  # Treat NaN values as 'low'
    for category, (lower, upper) in ranges.items():
        if lower <= value <= upper:
            return category
    return 'unknown'

# Apply categorization to 'Bwd Packets Normalized' column
df['Bwd Packets Category'] = df['Bwd Packets Normalized'].apply(lambda x: categorize_value(x, category_ranges))

# %%
essential_columns = [' Source IP', ' Destination IP',' Destination Port', ' Protocol', 'Fwd Packets Category', 'Bwd Packets Category', ' Flow Duration',]

# %%
# Drop non-essential columns
filtered_df = df[essential_columns]
print("\nFiltered dataset Summery")
# Function to convert IP addresses to first subnet
def convert_to_first_subnet(ip_address):
    octets = ip_address.split('.')
    octets[2] = '0'
    octets[3] = '0'
    return '.'.join(octets)


# Strip leading and trailing spaces from 'Source IP' and 'Destination IP' columns
filtered_df[' Source IP'] = filtered_df[' Source IP'].astype(str).str.strip()
filtered_df[' Destination IP'] = filtered_df[' Destination IP'].astype(str).str.strip()

# Apply the function to 'Source IP' and 'Destination IP' columns
filtered_df[' Source IP'] = filtered_df[' Source IP'].apply(convert_to_first_subnet)
filtered_df[' Destination IP'] = filtered_df[' Destination IP'].apply(convert_to_first_subnet)
# Out:
# Filtered dataset Summery
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12096\2115978181.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[' Source IP'] = filtered_df[' Source IP'].astype(str).str.strip()
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12096\2115978181.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[' Destination IP'] = filtered_df[' Destination IP'].astype(str).str.strip()
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12096\2115978181.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[' Source IP'] = filtered_df[' Source IP'].apply(convert_to_first_subnet)
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_12096\2115978181.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df[' Destination IP'] = filtered_df[' Destination IP'].apply(convert_to_first_subnet)

# %%
with_ID = filtered_df.copy()
with_ID.insert(0, 'alertID', range(len(with_ID)))
print("\nAdding a ID number for the records")
print(with_ID.head())

dataset_with_ID = with_ID.values.tolist()
# Out:
# Adding a ID number for the records
#    alertID   Source IP  Destination IP   Destination Port   Protocol  \
# 0        0  104.16.0.0     192.168.0.0              54865          6
# 1        1  104.16.0.0     192.168.0.0              55054          6
# 2        2  104.16.0.0     192.168.0.0              55055          6
# 3        3  104.17.0.0     192.168.0.0              46236          6
# 4        4  104.19.0.0     192.168.0.0              54863          6
#
#   Fwd Packets Category Bwd Packets Category   Flow Duration
# 0              fwd_low              Bwd_low               3
# 1              fwd_low              Bwd_low             109
# 2              fwd_low              Bwd_low              52
# 3              fwd_low              Bwd_low              34
# 4              fwd_low              Bwd_low               3

# %%
print("\nconverting the dataset in to a list")
dataset = [alert[1:] for alert in dataset_with_ID]
# Out:
# converting the dataset in to a list

# %%
# Convert each sublist to a tuple for hashability
data_tuples = [tuple(sublist) for sublist in dataset]

# Count occurrences of each unique record
record_counts = Counter(data_tuples)

print("\nnumber occurrences of each unique record")
print(f"{len(record_counts) }")
# Out:
# number occurrences of each unique record
# 470366

# %%
# Assuming 'filtered_df' is your DataFrame with categorical values

# Create a copy of the DataFrame
new_df = filtered_df.copy()

# Initialize a global mapping to keep track of numerical values
global_mapping = Counter()

# Initialize dictionaries to store both forward and reverse mappings
forward_mapping = {}
reverse_mapping = {}

# Replace categorical values with numerical values using global mapping
for column in new_df.columns:
    # Get unique values in the current column
    unique_values = new_df[column].unique()

    # Map each unique value to a numerical value based on global mapping
    forward_mapping[column] = {value: global_mapping.setdefault(value, len(global_mapping)) for value in unique_values}

    # Create a reverse mapping dictionary
    reverse_mapping[column] = {num: val for val, num in forward_mapping[column].items()}

    # Replace categorical values in the column with numerical values
    new_df[column] = new_df[column].map(forward_mapping[column])

# %%
# Calculate the count of unique values in the 'type' field
type_counts = df[' Label'].value_counts()

print("\nDisplay the count of unique values in Label")
print(type_counts)
# Out:
# Display the count of unique values in Label
#  Label
# BENIGN      414322
# PortScan    158930
# DDoS        128027
# Bot           1966
# Name: count, dtype: int64

# %%
combined_dict = {k: v for inner_dict in reverse_mapping.values() for k, v in inner_dict.items()}

item_dataset = [tuple(x) for x in new_df.to_records(index=False)]

# Add ID field to the start of each tuple
item_dataset_withID = [(i,) + record for i, record in enumerate(item_dataset)]

new_df.to_csv('data.txt', index=False, sep=' ', header=False)

# %%
# Run the algorithm

os.system("java -jar spmf.jar run FPMax data.txt output.txt 0.05%")

itemset_records_object = []
itemset_records_numbers = []

# Read the output file line by line
outFile = open("output.txt", 'r', encoding='utf-8')
for string in outFile:
    itemset = []
    parts = string.split('#SUP:')
    numbers = list(map(int, parts[0].split()))
    support_count = int(parts[1].strip())

    itemset_using_numbers = [numbers, support_count]
    itemset_records_numbers.append(itemset_using_numbers)

    # Translate numerical values to attribute names using reverse mapping
    attribute_names = [str(combined_dict[num]) for num in numbers]
    itemset = [attribute_names, support_count]
    # Output the result
    #print(f"Pattern: {' '.join(attribute_names)}, Support Count: {str(support_count)}")
    itemset_records_object.append(itemset)

outFile.close()

def return_unique_labels(alertID_List):
    # Filter DataFrame based on selected IDs
    selected_records = df.iloc[alertID_List]
    # Count unique values in a certain field (e.g., Field1) in the selected records
    unique_value_counts = selected_records[' Label'].value_counts()
    return(unique_value_counts)

for index,record in enumerate(itemset_records_numbers):
    itemset = record[0]
    containing_alerts = []
    for alert in item_dataset_withID:
        alert_items = set(alert[1:])  # Exclude the ID field
        if set(itemset).issubset(alert_items):
            containing_alerts.append(alert[0])  # Append the ID

    print(f"Pattern {index}: {itemset_records_object[index][0]}, \n{return_unique_labels(containing_alerts)}\n===============================================================================================================")
# Out:
# Pattern 0: ['192.168.0.0', 'Bwd_low', 'fwd_low', '229'],
#  Label
# BENIGN    353
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 1: ['192.168.0.0', 'Bwd_low', 'fwd_low', '142'],
#  Label
# BENIGN      346
# PortScan      8
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 2: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '136.243.0.0'],
#  Label
# BENIGN    354
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 3: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '185.13.0.0'],
#  Label
# BENIGN    357
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 4: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '38.69.0.0'],
#  Label
# BENIGN    359
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 5: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '192.0.0.0'],
#  Label
# BENIGN    361
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 6: ['192.168.0.0', 'Bwd_low', 'fwd_low', '242'],
#  Label
# BENIGN    362
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 7: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '54.243.0.0'],
#  Label
# BENIGN    363
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 8: ['192.168.0.0', 'Bwd_low', 'fwd_low', '244'],
#  Label
# BENIGN    363
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 9: ['192.168.0.0', 'Bwd_low', 'fwd_low', '145'],
#  Label
# BENIGN      357
# PortScan      7
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 10: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '185.86.0.0'],
#  Label
# BENIGN    364
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 11: ['192.168.0.0', 'Bwd_low', 'fwd_low', '245'],
#  Label
# BENIGN    365
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 12: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '23.4.0.0'],
#  Label
# BENIGN    365
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 13: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '209.48.0.0'],
#  Label
# BENIGN    367
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 14: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '54.225.0.0'],
#  Label
# BENIGN    370
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 15: ['192.168.0.0', 'Bwd_low', 'fwd_low', '247'],
#  Label
# BENIGN    372
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 16: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '52.216.0.0'],
#  Label
# BENIGN    373
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 17: ['192.168.0.0', 'Bwd_low', 'fwd_low', '232'],
#  Label
# BENIGN    374
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 18: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '109'],
#  Label
# PortScan    218
# BENIGN      145
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 19: ['192.168.0.0', 'Bwd_low', 'fwd_low', '251'],
#  Label
# BENIGN    377
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 20: ['192.168.0.0', 'Bwd_low', 'fwd_low', '233'],
#  Label
# BENIGN    377
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 21: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '23.199.0.0'],
#  Label
# BENIGN    380
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 22: ['192.168.0.0', 'Bwd_low', 'fwd_low', '250'],
#  Label
# BENIGN      381
# PortScan      1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 23: ['192.168.0.0', 'Bwd_low', 'fwd_low', '231'],
#  Label
# BENIGN    385
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 24: ['192.168.0.0', 'Bwd_low', 'fwd_low', '238'],
#  Label
# BENIGN    387
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 25: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '110'],
#  Label
# PortScan    220
# BENIGN      152
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 26: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '62.161.0.0'],
#  Label
# BENIGN    366
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 27: ['192.168.0.0', 'Bwd_low', 'fwd_low', '235'],
#  Label
# BENIGN      391
# PortScan      2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 28: ['192.168.0.0', 'fwd_low', '6', '172.16.0.0', '80', 'Bwd_medium'],
#  Label
# DDoS    371
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 29: ['192.168.0.0', 'Bwd_low', 'fwd_low', '249'],
#  Label
# BENIGN    395
# DDoS        1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 30: ['192.168.0.0', 'Bwd_low', 'fwd_low', '240'],
#  Label
# BENIGN    397
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 31: ['192.168.0.0', 'Bwd_low', 'fwd_low', '228'],
#  Label
# BENIGN    398
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 32: ['192.168.0.0', 'Bwd_low', 'fwd_low', '236'],
#  Label
# BENIGN      398
# PortScan      2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 33: ['192.168.0.0', 'Bwd_low', 'fwd_low', '239'],
#  Label
# BENIGN    400
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 34: ['192.168.0.0', 'Bwd_low', 'fwd_low', '264'],
#  Label
# BENIGN      242
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 35: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '23.203.0.0'],
#  Label
# BENIGN    400
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 36: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '104.79.0.0'],
#  Label
# BENIGN    402
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 37: ['192.168.0.0', 'Bwd_low', 'fwd_low', '230'],
#  Label
# BENIGN      402
# PortScan      1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 38: ['192.168.0.0', 'Bwd_low', 'fwd_low', '226'],
#  Label
# BENIGN      402
# PortScan      1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 39: ['192.168.0.0', 'Bwd_low', 'fwd_low', '227'],
#  Label
# BENIGN      402
# PortScan      1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 40: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '111'],
#  Label
# PortScan    238
# BENIGN      155
# Bot           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 41: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '74.217.0.0'],
#  Label
# BENIGN    407
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 42: ['192.168.0.0', 'Bwd_low', 'fwd_low', '147'],
#  Label
# BENIGN      399
# PortScan     10
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 43: ['192.168.0.0', 'Bwd_low', 'fwd_low', '248'],
#  Label
# BENIGN    410
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 44: ['192.168.0.0', 'Bwd_low', 'fwd_low', '237'],
#  Label
# BENIGN    414
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 45: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '104.244.0.0'],
#  Label
# BENIGN    421
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 46: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '107.178.0.0'],
#  Label
# BENIGN    422
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 47: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '241'],
#  Label
# BENIGN    426
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 48: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '133.237.0.0'],
#  Label
# BENIGN    429
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 49: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '148'],
#  Label
# BENIGN      423
# PortScan     11
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 50: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '106'],
#  Label
# PortScan    246
# BENIGN      179
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 51: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '66.235.0.0'],
#  Label
# BENIGN    436
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 52: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '192.243.0.0'],
#  Label
# BENIGN    437
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 53: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '213.180.0.0'],
#  Label
# BENIGN    442
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 54: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '50.116.0.0'],
#  Label
# BENIGN    363
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 55: ['192.168.0.0', 'Bwd_low', 'fwd_low', '259'],
#  Label
# BENIGN      292
# PortScan    160
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 56: ['192.168.0.0', 'Bwd_low', 'fwd_low', '255'],
#  Label
# BENIGN      293
# PortScan    161
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 57: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '224'],
#  Label
# BENIGN    379
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 58: ['192.168.0.0', 'Bwd_low', 'fwd_low', '256'],
#  Label
# BENIGN      298
# PortScan    160
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 59: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '225'],
#  Label
# BENIGN    368
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 60: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '104.31.0.0'],
#  Label
# BENIGN    462
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 61: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '98.139.0.0'],
#  Label
# BENIGN    462
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 62: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '150'],
#  Label
# BENIGN    372
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 63: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '220'],
#  Label
# BENIGN    371
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 64: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '209.85.0.0'],
#  Label
# BENIGN    465
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 65: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '221'],
#  Label
# BENIGN    388
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 66: ['192.168.0.0', 'Bwd_low', 'fwd_low', '254'],
#  Label
# BENIGN      310
# PortScan    158
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 67: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '223'],
#  Label
# BENIGN    391
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 68: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '54.192.0.0'],
#  Label
# BENIGN    470
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 69: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '445'],
#  Label
# BENIGN      267
# PortScan    180
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 70: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '218'],
#  Label
# BENIGN    414
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 71: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '149'],
#  Label
# BENIGN    379
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 72: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '72.30.0.0'],
#  Label
# BENIGN    512
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 73: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '23.23.0.0'],
#  Label
# BENIGN    514
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 74: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '214'],
#  Label
# BENIGN    425
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 75: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '100'],
#  Label
# PortScan    332
# BENIGN      178
# Bot           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 76: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '219'],
#  Label
# BENIGN    424
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 77: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '99'],
#  Label
# PortScan    350
# BENIGN      171
# Bot           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 78: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '104.25.0.0'],
#  Label
# BENIGN    528
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 79: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '23.21.0.0'],
#  Label
# BENIGN    530
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 80: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '129.146.0.0'],
#  Label
# BENIGN    530
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 81: ['192.168.0.0', 'Bwd_low', 'fwd_low', '146'],
#  Label
# BENIGN      374
# PortScan    160
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 82: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '199.244.0.0'],
#  Label
# BENIGN    435
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 83: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '96'],
#  Label
# PortScan    309
# BENIGN      218
# Bot           2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 84: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '23.111.0.0'],
#  Label
# BENIGN    541
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 85: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '152'],
#  Label
# BENIGN    449
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 86: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '151'],
#  Label
# BENIGN    430
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 87: ['192.168.0.0', 'Bwd_low', 'fwd_low', '143'],
#  Label
# BENIGN      377
# PortScan    170
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 88: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '216'],
#  Label
# BENIGN    442
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 89: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '217'],
#  Label
# BENIGN    460
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 90: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '135'],
#  Label
# BENIGN      272
# PortScan    171
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 91: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '8'],
#  Label
# PortScan    411
# BENIGN       11
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 92: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '74.125.0.0'],
#  Label
# BENIGN    557
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 93: ['192.168.0.0', 'Bwd_low', 'fwd_low', '144'],
#  Label
# BENIGN      391
# PortScan    174
# Bot           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 94: ['192.168.0.0', 'Bwd_low', 'fwd_low', '17', '123', '91.189.0.0'],
#  Label
# BENIGN    510
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 95: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '204.154.0.0'],
#  Label
# BENIGN    397
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 96: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '199.167.0.0'],
#  Label
# BENIGN    570
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 97: ['192.168.0.0', 'Bwd_low', 'fwd_low', '17', '123', '144.217.0.0'],
#  Label
# BENIGN    558
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 98: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '215'],
#  Label
# BENIGN    465
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 99: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '213'],
#  Label
# BENIGN    469
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 100: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '192.82.0.0'],
#  Label
# BENIGN    580
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 101: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '95'],
#  Label
# PortScan    330
# BENIGN      246
# Bot           4
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 102: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '210'],
#  Label
# BENIGN    483
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 103: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '138'],
#  Label
# BENIGN    496
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 104: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '74.117.0.0'],
#  Label
# BENIGN    595
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 105: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '154'],
#  Label
# BENIGN    501
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 106: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '153'],
#  Label
# BENIGN    501
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 107: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '93.184.0.0'],
#  Label
# BENIGN    383
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 108: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '207'],
#  Label
# BENIGN    528
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 109: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '206'],
#  Label
# BENIGN    535
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 110: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '205'],
#  Label
# BENIGN    545
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 111: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '159'],
#  Label
# BENIGN    549
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 112: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '222'],
#  Label
# BENIGN    381
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 113: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '200.147.0.0'],
#  Label
# BENIGN    359
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 114: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '94'],
#  Label
# PortScan    410
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 115: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '23.54.0.0'],
#  Label
# BENIGN    486
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 116: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '208'],
#  Label
# BENIGN    530
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 117: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '158'],
#  Label
# BENIGN    553
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 118: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '164'],
#  Label
# BENIGN    577
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 119: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '204'],
#  Label
# BENIGN    568
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 120: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '7'],
#  Label
# PortScan    478
# BENIGN       15
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 121: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '209'],
#  Label
# BENIGN    545
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 122: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '157'],
#  Label
# BENIGN    560
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 123: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '160'],
#  Label
# BENIGN    543
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 124: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '203'],
#  Label
# BENIGN    577
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 125: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '72.5.0.0'],
#  Label
# BENIGN    665
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 126: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '162.248.0.0'],
#  Label
# BENIGN    674
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 127: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '119.205.0.0'],
#  Label
# BENIGN    630
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 128: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '201'],
#  Label
# BENIGN    602
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 129: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '200'],
#  Label
# BENIGN    610
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 130: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '6', '3268'],
#  Label
# BENIGN      519
# PortScan    160
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 131: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '156'],
#  Label
# BENIGN    589
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 132: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '185'],
#  Label
# BENIGN    615
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 133: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '155'],
#  Label
# BENIGN    583
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 134: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '189'],
#  Label
# BENIGN    621
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 135: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '197'],
#  Label
# BENIGN    603
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 136: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '175'],
#  Label
# BENIGN    607
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 137: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '198'],
#  Label
# BENIGN    629
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 138: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '162'],
#  Label
# BENIGN    602
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 139: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '202'],
#  Label
# BENIGN    625
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 140: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '194'],
#  Label
# BENIGN    622
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 141: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '195'],
#  Label
# BENIGN    631
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 142: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '188'],
#  Label
# BENIGN    629
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 143: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '178'],
#  Label
# BENIGN    619
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 144: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '193'],
#  Label
# BENIGN    634
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 145: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '212'],
#  Label
# BENIGN    468
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 146: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '190'],
#  Label
# BENIGN    643
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 147: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '183'],
#  Label
# BENIGN    650
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 148: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '184'],
#  Label
# BENIGN    655
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 149: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '165'],
#  Label
# BENIGN    624
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 150: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '180'],
#  Label
# BENIGN    652
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 151: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '192'],
#  Label
# BENIGN    620
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 152: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '176'],
#  Label
# BENIGN    646
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 153: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '187'],
#  Label
# BENIGN    660
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 154: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '63.251.0.0'],
#  Label
# BENIGN    740
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 155: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '170'],
#  Label
# BENIGN    655
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 156: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '166'],
#  Label
# BENIGN    658
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 157: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '169'],
#  Label
# BENIGN    675
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 158: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '167'],
#  Label
# BENIGN    659
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 159: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '182'],
#  Label
# BENIGN    668
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 160: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '186'],
#  Label
# BENIGN    661
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 161: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '181'],
#  Label
# BENIGN    666
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 162: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '172'],
#  Label
# BENIGN    648
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 163: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '211'],
#  Label
# BENIGN    512
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 164: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '196'],
#  Label
# BENIGN    680
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 165: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '152.163.0.0'],
#  Label
# BENIGN    767
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 166: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '91'],
#  Label
# PortScan    517
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 167: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '93'],
#  Label
# PortScan    541
# BENIGN        2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 168: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '174'],
#  Label
# BENIGN    689
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 169: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '87'],
#  Label
# PortScan    459
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 170: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '98'],
#  Label
# PortScan    538
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 171: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '173'],
#  Label
# BENIGN    689
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 172: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '9'],
#  Label
# PortScan    623
# BENIGN        3
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 173: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '177'],
#  Label
# BENIGN    685
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 174: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '191'],
#  Label
# BENIGN    690
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 175: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '168'],
#  Label
# BENIGN    716
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 176: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '171'],
#  Label
# BENIGN    716
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 177: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '90'],
#  Label
# PortScan    548
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 178: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '10'],
#  Label
# PortScan    695
# BENIGN        3
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 179: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '86'],
#  Label
# PortScan    560
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 180: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '163'],
#  Label
# BENIGN    597
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 181: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '199'],
#  Label
# BENIGN    603
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 182: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '72.167.0.0'],
#  Label
# BENIGN    781
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 183: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '205.185.0.0'],
#  Label
# BENIGN    437
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 184: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '161'],
#  Label
# BENIGN    566
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 185: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '89'],
#  Label
# PortScan    571
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 186: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '97'],
#  Label
# PortScan    616
# BENIGN        1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 187: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '178.172.0.0'],
#  Label
# BENIGN    857
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 188: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '173.194.0.0', '465'],
#  Label
# BENIGN    357
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 189: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '6', '139'],
#  Label
# BENIGN      535
# PortScan    203
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 190: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '92'],
#  Label
# PortScan    680
# DDoS          2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 191: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '8.43.0.0'],
#  Label
# BENIGN    373
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 192: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '192.229.0.0'],
#  Label
# BENIGN    354
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 193: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '67.72.0.0'],
#  Label
# BENIGN    951
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 194: ['192.168.0.0', '192.168.0.0', 'Bwd_low', 'fwd_low', '17', '53', '179'],
#  Label
# BENIGN    720
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 195: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '82'],
#  Label
# PortScan    713
# DDoS          1
# BENIGN        1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 196: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '173.194.0.0'],
#  Label
# BENIGN    397
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 197: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '23.50.0.0'],
#  Label
# BENIGN    761
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 198: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '81'],
#  Label
# PortScan    730
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 199: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '78'],
#  Label
# PortScan    709
# Name: count, dtype: int64
# ===============================================================================================================
# ...
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 271: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '50.63.0.0'],
#  Label
# BENIGN    2020
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 272: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '60'],
#  Label
# PortScan    1804
# BENIGN         2
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 273: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '64'],
#  Label
# PortScan    1822
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 274: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '59'],
#  Label
# PortScan    1821
# DDoS           3
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 275: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '58'],
#  Label
# PortScan    1775
# DDoS           1
# BENIGN         1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 276: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '57'],
#  Label
# PortScan    1779
# DDoS           2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 277: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '74'],
#  Label
# PortScan    1981
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 278: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '104.97.0.0'],
#  Label
# BENIGN    1130
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 279: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '61'],
#  Label
# PortScan    1856
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 280: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '23.61.0.0'],
#  Label
# BENIGN    1639
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 281: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '23.208.0.0'],
#  Label
# BENIGN    975
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 282: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '23.208.0.0'],
#  Label
# BENIGN    464
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 283: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '62'],
#  Label
# PortScan    2075
# BENIGN         2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 284: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '51'],
#  Label
# PortScan    1891
# BENIGN         2
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 285: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '205.174.0.0', '8080'],
#  Label
# Bot       1257
# BENIGN     966
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 286: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '52'],
#  Label
# PortScan    1907
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 287: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '56'],
#  Label
# PortScan    2077
# DDoS           1
# BENIGN         1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 288: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '21'],
#  Label
# PortScan    1147
# BENIGN         1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 289: ['192.168.0.0', '192.168.0.0', '21'],
#  Label
# BENIGN      1495
# PortScan    1147
# Bot           21
# DDoS           2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 290: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '23.194.0.0'],
#  Label
# BENIGN    1165
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 291: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '23.194.0.0'],
#  Label
# BENIGN    479
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 292: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '63'],
#  Label
# PortScan    2298
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 293: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '41'],
#  Label
# PortScan    2433
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 294: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '47'],
#  Label
# PortScan    2220
# DDoS           1
# BENIGN         1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 295: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '68.67.0.0'],
#  Label
# BENIGN    1651
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 296: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '68.67.0.0'],
#  Label
# BENIGN    696
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 297: ['192.168.0.0', 'Bwd_low', '6', '172.16.0.0', 'fwd_medium'],
#  Label
# BENIGN    3186
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 298: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '46'],
#  Label
# PortScan    2822
# BENIGN         1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 299: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '50'],
#  Label
# PortScan    2723
# DDoS           2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 300: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '1'],
#  Label
# BENIGN    449
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 301: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '1'],
#  Label
# PortScan    625
# BENIGN      243
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 302: ['192.168.0.0', '192.168.0.0', '1'],
#  Label
# BENIGN      3031
# PortScan     625
# Bot            5
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 303: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '22'],
#  Label
# PortScan    1108
# DDoS           3
# BENIGN         1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 304: ['192.168.0.0', '192.168.0.0', '22'],
#  Label
# BENIGN      2543
# PortScan    1108
# Bot           10
# DDoS           3
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 305: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '162.208.0.0'],
#  Label
# BENIGN    2059
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 306: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '162.208.0.0'],
#  Label
# BENIGN    463
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 307: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '55'],
#  Label
# PortScan    3210
# DDoS           1
# BENIGN         1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 308: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '178.255.0.0'],
#  Label
# BENIGN    3859
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 309: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '72.21.0.0'],
#  Label
# BENIGN    506
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 310: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '72.21.0.0'],
#  Label
# BENIGN    2087
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 311: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '54'],
#  Label
# PortScan    3533
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 312: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '45'],
#  Label
# PortScan    5018
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 313: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '151.101.0.0', '4'],
#  Label
# BENIGN    453
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 314: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.217.0.0', '4'],
#  Label
# BENIGN    701
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 315: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '4'],
#  Label
# BENIGN    739
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 316: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '4'],
#  Label
# PortScan    550
# BENIGN       28
# DDoS          4
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 317: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '3', '151.101.0.0'],
#  Label
# BENIGN    369
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 318: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '151.101.0.0'],
#  Label
# BENIGN    818
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 319: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '42'],
#  Label
# PortScan    5877
# BENIGN         1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 320: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '48'],
#  Label
# PortScan    5385
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 321: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '52.84.0.0'],
#  Label
# BENIGN    2841
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 322: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '52.84.0.0'],
#  Label
# BENIGN    994
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 323: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '49'],
#  Label
# PortScan    7897
# BENIGN         1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 324: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.217.0.0', '3'],
#  Label
# BENIGN    1444
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 325: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '3'],
#  Label
# PortScan    598
# BENIGN       70
# DDoS          1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 326: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '44'],
#  Label
# PortScan    11749
# DDoS            2
# BENIGN          2
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 327: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '43'],
#  Label
# PortScan    12816
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 328: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '443', '172.217.0.0'],
#  Label
# BENIGN    11022
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 329: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '80', '172.217.0.0'],
#  Label
# BENIGN    2939
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 330: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '80'],
#  Label
# DDoS        127652
# PortScan       993
# BENIGN          11
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 331: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '53'],
#  Label
# PortScan    2535
# BENIGN         2
# DDoS           1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 332: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '172.16.0.0', '17'],
#  Label
# PortScan    1288
# DDoS           1
# BENIGN         1
# Name: count, dtype: int64
# ===============================================================================================================
# Pattern 333: ['192.168.0.0', 'Bwd_low', 'fwd_low', '6', '6'],
#  Label
# BENIGN      222136
# PortScan    158923
# DDoS        127655
# Bot           1966
# Name: count, dtype: int64
# ===============================================================================================================
